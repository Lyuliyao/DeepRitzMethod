# %%
using Flux.Tracker
using Flux
using Flux:throttle,glorot_uniform
using BSON:@save
using BSON:@load
using Base.Iterators: repeated
using Flux:@treelike
using PyPlot
using FastGaussQuadrature
using SparseGrids
using LinearAlgebra
using Flux: @epochs
using DataFrames
using CSV
using Sobol
using Pkg; Pkg.activate("cuda"); Pkg.instantiate()
using CuArrays
using ForwardDiff
using CUDAnative
CuArrays.culiteral_pow(::typeof(^), x::ForwardDiff.Dual{Nothing,Float32,1}, ::Val{2}) = x*x
CuArrays.culiteral_pow(::typeof(^), x::ForwardDiff.Dual{Nothing,Float64,1}, ::Val{2}) = x*x

f(x)=2*π^2 .*sum(cos.(π*x[i,:]') for i=1:2, dims=1)
acti(x)=@. x/(1+CUDAnative.exp(-x))


struct Block{F,S,T}
  W1::S
  W2::S
  b1::T
  b2::T
  σ::F
end

Block(W1 , W2, b1, b2) = Block(W1,W2 ,b1 ,b2, identity)

function Block(in1::Integer,in2::Integer, out1::Integer,out2::Integer, σ = identity;
  initW1 = glorot_uniform, initW2 =glorot_uniform, initb1 = zeros,initb2=zeros)
  return Block(param(initW1(out1, in1)),param(initW2(out2,in2)), param(initb1(out1)), param(initb2(out2)),σ)
end

@treelike Block

function (a::Block)(x)
  W1,W2, b1,b2, σ = a.W1,a.W2,a.b1, a.b2, a.σ
  σ.(W2 *σ.(W1*x .+ b1) .+ b2) .+ x
end




M=Chain(
Dense(2,10),
Block(10,10,10,10,acti),
Block(10,10,10,10,acti),
Block(10,10,10,10,acti),
Block(10,10,10,10,acti),
Dense(10,1)
)|>gpu

function lossFD(N)
  notes=rand(2,N)
  notes =notes |>gpu
  d=rand(1)/100 |>gpu
  losses=0
  MMM=M(notes)
  for i=1:2
    l1=zeros(2)
    l1[i]=1
    l1 = l1 |>gpu
    losses  += (sum(0.5*((M(notes .+ d.*l1) .- MMM)./d).^2)/N)[1]
  end
  losses += (sum(0.5*(π^2 * (MMM).^2))/N)[1]
  losses += (sum(-f(notes) .*MMM)/N)[1]
  return losses
end



function lossBC(β)
  d=(rand(1)/100)|>gpu
  point=zeros(2,400)
  p=rand(1,100)
  for i=1:2
    point[:,200*(i-1)+1:200*(i-1)+100]=vcat(p[1:i-1,:],zeros(100)',p[i:end,:])
    point[:,200*(i-1)+101:200*i]=vcat(p[1:i-1,:], ones(100)',p[i:end,:])
  end
    point=point|>gpu
  losses=0
  for i=1:2
    l2=zeros(2)
    l1=zeros(2)
    l2[i]=2
    l1[i]=1
    l1=l1|>gpu
    l2=l2|>gpu
    losses +=β*(sum((( 1/2*M(point[:,200*(i-1)+1:200*i] .+ d.*l1) .- 1/2*M(point[:,200*(i-1)+1:200*i] .- d.*l1))./d).^2)/100)[1]
  end
  return losses
end

function loss1(N)
  return lossBC(50)+lossFD(N)
end

function loss_true(xx=1,yy=1,xx1=1,xx2=2)
  points=rand(2,2000)|>gpu
  F_true(x)= sum(cos.(pi*x[i,:]') for i=1:2, dims=1)
  errors=sqrt(sum((M(points)-F_true(points)).^2)/2000)
  return errors
end

inner=SobolSeq(2)
BC=SobolSeq(1)
function test(N;traintime=2000)
  errdf=DataFrame(time=Int[],absolute_error=Float64[],loss_FD=Float64[],loss_BC=Float64[])
  cntr=1
  evalcb = function()
    loss_true1=loss_true()
    loss_FD = lossFD(N)
    loss_BC =lossBC(1)
    push!(errdf,[Tracker.data(cntr),Tracker.data(loss_true1),Tracker.data(loss_FD),Tracker.data(loss_BC)])
    cntr+=1
    if cntr%1000==0
      @show(cntr,loss_FD,loss_true1,loss_BC)
      CSV.write("$(N)rand2Dexm2.csv",errdf)
      @save "$(N)randpoint2Dexm2m.bson" M
      weights=Tracker.data.(params(M))
      @save "$(N)randpoint2Dexm2w.bson" weights
    end
  end
  θ=Flux.params(M)
  opt=ADAM()
  dataset=[(N) for i=1:traintime]
  Flux.train!(loss1, params(M), zip(dataset), opt, cb=evalcb)
  return errdf
end
# Out:
# Activating new environment at `~/2Dexm2/cuda/Project.toml`
#   Updating registry at `~/.julia/registries/General`
#   Updating git-repo `https://github.com/JuliaRegistries/General.git`
# Fetching: [========================================>]  100.0 %.0 % Resolving package versions...
# test (generic function with 1 method)

# %%
for i=1:4
    N=[250 500 1000 2000]
    M=Chain(
        Dense(2,10),
        Block(10,10,10,10,acti),
        Block(10,10,10,10,acti),
        Block(10,10,10,10,acti),
        Block(10,10,10,10,acti),
        Dense(10,1)
        )|>gpu
    errdf=test(N[i],traintime=100000)
end
# Out:
# cntr = 1000
# loss_FD = -7.903569005139207 (tracked)
# loss_true1 = 0.46685845f0 (tracked)
# loss_BC = 0.003965439620820977 (tracked)
# cntr = 2000
# loss_FD = -11.634361023088005 (tracked)
# loss_true1 = 0.020110203f0 (tracked)
# loss_BC = 0.0004659452429950963 (tracked)
# cntr = 3000
# loss_FD = -10.942559085653706 (tracked)
# loss_true1 = 0.023106731f0 (tracked)
# loss_BC = 0.0003838518650108326 (tracked)
# cntr = 4000
# loss_FD = -10.116635241208403 (tracked)
# loss_true1 = 0.05469218f0 (tracked)
# loss_BC = 0.00018462389427014039 (tracked)
# cntr = 5000
# loss_FD = -9.337664303317037 (tracked)
# loss_true1 = 0.00967024f0 (tracked)
# loss_BC = 0.00014354424296791682 (tracked)
# cntr = 6000
# loss_FD = -9.519744221502279 (tracked)
# loss_true1 = 0.009619538f0 (tracked)
# loss_BC = 0.0003055643070125184 (tracked)
# cntr = 7000
# loss_FD = -12.13728814091478 (tracked)
# loss_true1 = 0.020308843f0 (tracked)
# loss_BC = 0.0006841213231191515 (tracked)
# cntr = 8000
# loss_FD = -10.47404126586476 (tracked)
# loss_true1 = 0.014249951f0 (tracked)
# loss_BC = 0.0002442735351544761 (tracked)
# cntr = 9000
# loss_FD = -12.046097192082703 (tracked)
# loss_true1 = 0.013367023f0 (tracked)
# loss_BC = 0.00010714606444243695 (tracked)
# cntr = 10000
# loss_FD = -10.844413869092506 (tracked)
# loss_true1 = 0.0356636f0 (tracked)
# loss_BC = 0.00011222193952577444 (tracked)
# cntr = 11000
# loss_FD = -9.63397673561437 (tracked)
# loss_true1 = 0.0069004497f0 (tracked)
# loss_BC = 4.110538711310612e-5 (tracked)
# cntr = 12000
# loss_FD = -9.00254668447915 (tracked)
# loss_true1 = 0.029517232f0 (tracked)
# loss_BC = 0.00025628483712063064 (tracked)
# cntr = 13000
# loss_FD = -9.168591397073378 (tracked)
# loss_true1 = 0.026296126f0 (tracked)
# loss_BC = 0.00022300148490798826 (tracked)
# cntr = 14000
# loss_FD = -9.410857553339387 (tracked)
# loss_true1 = 0.011589431f0 (tracked)
# loss_BC = 0.00011847670133694456 (tracked)
# cntr = 15000
# loss_FD = -10.709011549090809 (tracked)
# loss_true1 = 0.017531838f0 (tracked)
# loss_BC = 0.00016469951795384418 (tracked)
# cntr = 16000
# loss_FD = -9.471706167816475 (tracked)
# loss_true1 = 0.023849528f0 (tracked)
# loss_BC = 8.095820525521578e-5 (tracked)
# cntr = 17000
# loss_FD = -8.346061497520392 (tracked)
# loss_true1 = 0.01977792f0 (tracked)
# loss_BC = 0.0001345466514140036 (tracked)
# cntr = 18000
# loss_FD = -9.934934639364194 (tracked)
# loss_true1 = 0.025445197f0 (tracked)
# loss_BC = 0.00047035283301819766 (tracked)
# cntr = 19000
# loss_FD = -10.481223188329123 (tracked)
# loss_true1 = 0.021160621f0 (tracked)
# loss_BC = 2.6286108055300986e-5 (tracked)
# cntr = 20000
# loss_FD = -10.367329425906169 (tracked)
# loss_true1 = 0.008185656f0 (tracked)
# loss_BC = 0.00018019033204495343 (tracked)
# cntr = 21000
# loss_FD = -9.92243935962294 (tracked)
# loss_true1 = 0.015354828f0 (tracked)
# loss_BC = 0.00016294549522590464 (tracked)
# cntr = 22000
# loss_FD = -9.744730930903398 (tracked)
# loss_true1 = 0.033449728f0 (tracked)
# loss_BC = 0.00010076541986265444 (tracked)
# cntr = 23000
# loss_FD = -10.018522847393966 (tracked)
# loss_true1 = 0.023826167f0 (tracked)
# loss_BC = 0.00017021828154882283 (tracked)
# cntr = 24000
# loss_FD = -9.853601582141634 (tracked)
# loss_true1 = 0.01118193f0 (tracked)
# loss_BC = 1.7779976164139153e-5 (tracked)
# cntr = 25000
# loss_FD = -7.91828693953687 (tracked)
# loss_true1 = 0.03158367f0 (tracked)
# loss_BC = 0.00033754141586518746 (tracked)
# cntr = 26000
# loss_FD = -12.834429524349957 (tracked)
# loss_true1 = 0.028182676f0 (tracked)
# loss_BC = 0.0002720054532319135 (tracked)
# cntr = 27000
# loss_FD = -9.699990397322397 (tracked)
# loss_true1 = 0.017424054f0 (tracked)
# loss_BC = 0.00013659706405409148 (tracked)
# cntr = 28000
# loss_FD = -10.61654100487222 (tracked)
# loss_true1 = 0.048001945f0 (tracked)
# loss_BC = 0.00011096525836702496 (tracked)
# cntr = 29000
# loss_FD = -8.399397867431663 (tracked)
# loss_true1 = 0.019767543f0 (tracked)
# loss_BC = 6.80711010304686e-5 (tracked)
# cntr = 30000
# loss_FD = -10.848508032236932 (tracked)
# loss_true1 = 0.022590822f0 (tracked)
# loss_BC = 0.00020590224047252297 (tracked)
# cntr = 31000
# loss_FD = -10.190781902429997 (tracked)
# loss_true1 = 0.0075779073f0 (tracked)
# loss_BC = 0.0001538157917744802 (tracked)
# cntr = 32000
# loss_FD = -10.49060748338173 (tracked)
# loss_true1 = 0.01106325f0 (tracked)
# loss_BC = 7.88438040696997e-5 (tracked)
# cntr = 33000
# loss_FD = -8.158782476040003 (tracked)
# loss_true1 = 0.039490275f0 (tracked)
# loss_BC = 0.00018766655550383812 (tracked)
# cntr = 34000
# loss_FD = -11.057285639935708 (tracked)
# loss_true1 = 0.018727297f0 (tracked)
# loss_BC = 6.386445044930542e-5 (tracked)
# cntr = 35000
# loss_FD = -9.36756064886633 (tracked)
# loss_true1 = 0.025351098f0 (tracked)
# loss_BC = 0.00010311032686187129 (tracked)
# cntr = 36000
# loss_FD = -9.993977631219284 (tracked)
# loss_true1 = 0.01127437f0 (tracked)
# loss_BC = 0.0001630153210303132 (tracked)
# cntr = 37000
# loss_FD = -11.23470997987525 (tracked)
# loss_true1 = 0.021578128f0 (tracked)
# loss_BC = 0.00013409416686130575 (tracked)
# cntr = 38000
# loss_FD = -9.497920306403437 (tracked)
# loss_true1 = 0.017735517f0 (tracked)
# loss_BC = 0.00011440196627658748 (tracked)
# cntr = 39000
# loss_FD = -11.453960712180061 (tracked)
# loss_true1 = 0.025737064f0 (tracked)
# loss_BC = 0.0002905285673445292 (tracked)
# cntr = 40000
# loss_FD = -12.787458092826675 (tracked)
# loss_true1 = 0.008161468f0 (tracked)
# loss_BC = 0.00010445543241776169 (tracked)
# cntr = 41000
# loss_FD = -9.485841282255429 (tracked)
# loss_true1 = 0.015592968f0 (tracked)
# loss_BC = 9.125636944727603e-5 (tracked)
# cntr = 42000
# loss_FD = -8.771285822690949 (tracked)
# loss_true1 = 0.017889777f0 (tracked)
# loss_BC = 0.0002954753540858333 (tracked)
# cntr = 43000
# loss_FD = -10.083350484253433 (tracked)
# loss_true1 = 0.017127205f0 (tracked)
# loss_BC = 3.0868461597725934e-5 (tracked)
# cntr = 44000
# loss_FD = -9.686409632470541 (tracked)
# loss_true1 = 0.057584353f0 (tracked)
# loss_BC = 9.74971824627795e-5 (tracked)
# cntr = 45000
# loss_FD = -9.272468951052353 (tracked)
# loss_true1 = 0.024360085f0 (tracked)
# loss_BC = 5.9646489649235333e-5 (tracked)
# cntr = 46000
# loss_FD = -10.978630965520338 (tracked)
# loss_true1 = 0.014430484f0 (tracked)
# loss_BC = 4.1938954046282816e-5 (tracked)
# cntr = 47000
# loss_FD = -11.30355867496059 (tracked)
# loss_true1 = 0.0121965865f0 (tracked)
# loss_BC = 6.896611944352398e-5 (tracked)
# cntr = 48000
# loss_FD = -11.73338150622109 (tracked)
# loss_true1 = 0.014798535f0 (tracked)
# loss_BC = 7.422763630428325e-5 (tracked)
# cntr = 49000
# loss_FD = -7.4749883202490395 (tracked)
# loss_true1 = 0.023654802f0 (tracked)
# loss_BC = 6.297691875551698e-5 (tracked)
# cntr = 50000
# loss_FD = -9.588513150525651 (tracked)
# loss_true1 = 0.014195512f0 (tracked)
# loss_BC = 0.00019947261663795382 (tracked)
# cntr = 51000
# loss_FD = -11.094027936201073 (tracked)
# loss_true1 = 0.012574773f0 (tracked)
# loss_BC = 0.00012065955304657514 (tracked)
# cntr = 52000
# loss_FD = -8.837255901384307 (tracked)
# loss_true1 = 0.005420919f0 (tracked)
# loss_BC = 0.00011057831206118748 (tracked)
# cntr = 53000
# loss_FD = -8.139558778576928 (tracked)
# loss_true1 = 0.01644996f0 (tracked)
# loss_BC = 7.712618130133937e-5 (tracked)
# cntr = 54000
# loss_FD = -9.472495032630908 (tracked)
# loss_true1 = 0.010416932f0 (tracked)
# loss_BC = 0.00010551537256781225 (tracked)
# cntr = 55000
# loss_FD = -10.721087897671369 (tracked)
# loss_true1 = 0.026528813f0 (tracked)
# loss_BC = 2.890602302818899e-5 (tracked)
# cntr = 56000
# loss_FD = -8.218527935528606 (tracked)
# loss_true1 = 0.025995452f0 (tracked)
# loss_BC = 0.00020191318744078502 (tracked)
# cntr = 57000
# loss_FD = -8.502535104186347 (tracked)
# loss_true1 = 0.023401875f0 (tracked)
# loss_BC = 0.0005036259791927891 (tracked)
# cntr = 58000
# loss_FD = -10.817869471284546 (tracked)
# loss_true1 = 0.0044658626f0 (tracked)
# loss_BC = 5.691429825435801e-5 (tracked)
# cntr = 59000
# loss_FD = -11.156501739136713 (tracked)
# loss_true1 = 0.02889259f0 (tracked)
# loss_BC = 3.421794355315269e-5 (tracked)
# cntr = 60000
# loss_FD = -10.670090663304073 (tracked)
# loss_true1 = 0.025029762f0 (tracked)
# loss_BC = 3.177452564280796e-5 (tracked)
# cntr = 61000
# loss_FD = -9.165468771447639 (tracked)
# loss_true1 = 0.035465833f0 (tracked)
# loss_BC = 7.35489271478771e-5 (tracked)
# cntr = 62000
# loss_FD = -10.259797009898316 (tracked)
# loss_true1 = 0.014799588f0 (tracked)
# loss_BC = 6.773370667014013e-5 (tracked)
# cntr = 63000
# loss_FD = -10.993848634248405 (tracked)
# loss_true1 = 0.01043165f0 (tracked)
# loss_BC = 3.075201350591768e-5 (tracked)
# cntr = 64000
# loss_FD = -9.749672708945376 (tracked)
# loss_true1 = 0.017957633f0 (tracked)
# loss_BC = 0.0004050347574311396 (tracked)
# cntr = 65000
# loss_FD = -9.127710832859577 (tracked)
# loss_true1 = 0.015654743f0 (tracked)
# loss_BC = 0.00016194481025464107 (tracked)
# cntr = 66000
# loss_FD = -9.344679590003633 (tracked)
# loss_true1 = 0.020640887f0 (tracked)
# loss_BC = 3.2825688806068855e-5 (tracked)
# cntr = 67000
# loss_FD = -8.294041169051733 (tracked)
# loss_true1 = 0.00974909f0 (tracked)
# loss_BC = 4.78536574790026e-5 (tracked)
# cntr = 68000
# loss_FD = -9.506550506017916 (tracked)
# loss_true1 = 0.0277714f0 (tracked)
# loss_BC = 0.00026756985556422065 (tracked)
# cntr = 69000
# loss_FD = -10.30949649225498 (tracked)
# loss_true1 = 0.018616829f0 (tracked)
# loss_BC = 0.00014156905136750901 (tracked)
# cntr = 70000
# loss_FD = -7.82298119850784 (tracked)
# loss_true1 = 0.010961526f0 (tracked)
# loss_BC = 8.194480129020957e-5 (tracked)
# cntr = 71000
# loss_FD = -9.219278590963278 (tracked)
# loss_true1 = 0.026426315f0 (tracked)
# loss_BC = 0.000113850853700082 (tracked)
# cntr = 72000
# loss_FD = -9.407990260684404 (tracked)
# loss_true1 = 0.02200054f0 (tracked)
# loss_BC = 5.2600024442711857e-5 (tracked)
# cntr = 73000
# loss_FD = -8.7761468626778 (tracked)
# loss_true1 = 0.02013943f0 (tracked)
# loss_BC = 0.00010254799388413269 (tracked)
# cntr = 74000
# loss_FD = -10.396725057363764 (tracked)
# loss_true1 = 0.020390026f0 (tracked)
# loss_BC = 1.785521011041054e-5 (tracked)
# cntr = 75000
# loss_FD = -9.797472317269925 (tracked)
# loss_true1 = 0.011396831f0 (tracked)
# loss_BC = 3.563448306491603e-5 (tracked)
# cntr = 76000
# loss_FD = -10.547309610439871 (tracked)
# loss_true1 = 0.006393101f0 (tracked)
# loss_BC = 0.00011254720237602117 (tracked)
# cntr = 77000
# loss_FD = -8.732998860029852 (tracked)
# loss_true1 = 0.04079365f0 (tracked)
# loss_BC = 4.3006004665387686e-5 (tracked)
# cntr = 78000
# loss_FD = -10.276265502978703 (tracked)
# loss_true1 = 0.028356086f0 (tracked)
# loss_BC = 2.734880979486587e-5 (tracked)
# cntr = 79000
# loss_FD = -9.463767082967223 (tracked)
# loss_true1 = 0.01733703f0 (tracked)
# loss_BC = 2.7458600025157944e-5 (tracked)
# cntr = 80000
# loss_FD = -9.98893044078575 (tracked)
# loss_true1 = 0.037710913f0 (tracked)
# loss_BC = 0.00016167885428864062 (tracked)
# cntr = 81000
# loss_FD = -12.634560728136737 (tracked)
# loss_true1 = 0.012542424f0 (tracked)
# loss_BC = 9.117902300081977e-5 (tracked)
# cntr = 82000
# loss_FD = -11.057083501121053 (tracked)
# loss_true1 = 0.028208999f0 (tracked)
# loss_BC = 0.00014313524708353665 (tracked)
# cntr = 83000
# loss_FD = -10.30529911367306 (tracked)
# loss_true1 = 0.0047213593f0 (tracked)
# loss_BC = 3.96470230199559e-5 (tracked)
# cntr = 84000
# loss_FD = -9.01783749755812 (tracked)
# loss_true1 = 0.018350903f0 (tracked)
# loss_BC = 0.00017500946077161385 (tracked)
# cntr = 85000
# loss_FD = -10.255814318596641 (tracked)
# loss_true1 = 0.015477469f0 (tracked)
# loss_BC = 5.720322190009776e-5 (tracked)
# cntr = 86000
# loss_FD = -10.555116566190899 (tracked)
# loss_true1 = 0.038325667f0 (tracked)
# loss_BC = 0.00010720568906518115 (tracked)
# cntr = 87000
# loss_FD = -10.147189389852839 (tracked)
# loss_true1 = 0.0101031745f0 (tracked)
# loss_BC = 2.3834599083617806e-5 (tracked)
# cntr = 88000
# loss_FD = -10.938594158641362 (tracked)
# loss_true1 = 0.013489893f0 (tracked)
# loss_BC = 6.937050920870645e-5 (tracked)
# cntr = 89000
# loss_FD = -9.904905538963003 (tracked)
# loss_true1 = 0.021913417f0 (tracked)
# loss_BC = 0.00013679391303573362 (tracked)
# cntr = 90000
# loss_FD = -8.722419341776794 (tracked)
# loss_true1 = 0.012389444f0 (tracked)
# loss_BC = 7.917111395023151e-5 (tracked)
# cntr = 91000
# loss_FD = -8.980217185472359 (tracked)
# loss_true1 = 0.018839775f0 (tracked)
# loss_BC = 5.7948513374576446e-5 (tracked)
# cntr = 92000
# loss_FD = -7.375333307447917 (tracked)
# loss_true1 = 0.022748038f0 (tracked)
# loss_BC = 4.679405092619757e-5 (tracked)
# cntr = 93000
# loss_FD = -8.46382509439838 (tracked)
# loss_true1 = 0.01271179f0 (tracked)
# loss_BC = 3.2940261141380147e-5 (tracked)
# cntr = 94000
# loss_FD = -9.356954764894652 (tracked)
# loss_true1 = 0.011310232f0 (tracked)
# loss_BC = 2.6571879336403483e-5 (tracked)
# cntr = 95000
# loss_FD = -9.961664066715766 (tracked)
# loss_true1 = 0.015480186f0 (tracked)
# loss_BC = 2.6727501234225217e-5 (tracked)
# cntr = 96000
# loss_FD = -9.476998155807014 (tracked)
# loss_true1 = 0.017361445f0 (tracked)
# loss_BC = 0.00020553996777497474 (tracked)
# cntr = 97000
# loss_FD = -11.63658676253348 (tracked)
# loss_true1 = 0.011580901f0 (tracked)
# loss_BC = 3.730422657989801e-5 (tracked)
# cntr = 98000
# loss_FD = -9.62192329575888 (tracked)
# loss_true1 = 0.012624292f0 (tracked)
# loss_BC = 5.4519443558553735e-5 (tracked)
# cntr = 99000
# loss_FD = -8.870092855994436 (tracked)
# loss_true1 = 0.021656562f0 (tracked)
# loss_BC = 2.4180976945626565e-5 (tracked)
# cntr = 100000
# loss_FD = -9.857960188771631 (tracked)
# loss_true1 = 0.022993263f0 (tracked)
# loss_BC = 9.245746932565146e-5 (tracked)
# cntr = 1000
# loss_FD = -4.666228680660414 (tracked)
# loss_true1 = 0.6839127f0 (tracked)
# loss_BC = 0.0008714761622175184 (tracked)
# cntr = 2000
# loss_FD = -10.83037042421397 (tracked)
# loss_true1 = 0.02329769f0 (tracked)
# loss_BC = 6.149139448984899e-5 (tracked)
# cntr = 3000
# loss_FD = -9.039284043422473 (tracked)
# loss_true1 = 0.025769947f0 (tracked)
# loss_BC = 0.00028031949774015065 (tracked)
# cntr = 4000
# loss_FD = -10.770249746301394 (tracked)
# loss_true1 = 0.029343547f0 (tracked)
# loss_BC = 0.0007667133180258956 (tracked)
# cntr = 5000
# loss_FD = -10.511027836728275 (tracked)
# loss_true1 = 0.01430166f0 (tracked)
# loss_BC = 4.322870981587604e-5 (tracked)
# cntr = 6000
# loss_FD = -10.367572109966167 (tracked)
# loss_true1 = 0.03463026f0 (tracked)
# loss_BC = 0.00023781161987851656 (tracked)
# cntr = 7000
# loss_FD = -10.218693950592362 (tracked)
# loss_true1 = 0.01505148f0 (tracked)
# loss_BC = 0.00015802444222178585 (tracked)
# cntr = 8000
# loss_FD = -9.237642685010584 (tracked)
# loss_true1 = 0.029799812f0 (tracked)
# loss_BC = 0.0003527904095234223 (tracked)
# cntr = 9000
# loss_FD = -8.84466734709319 (tracked)
# loss_true1 = 0.010190427f0 (tracked)
# loss_BC = 3.8226183751325173e-5 (tracked)
# cntr = 10000
# loss_FD = -8.686256858705583 (tracked)
# loss_true1 = 0.012138576f0 (tracked)
# loss_BC = 0.00012332396076932044 (tracked)
# cntr = 11000
# loss_FD = -9.75693306126227 (tracked)
# loss_true1 = 0.010360871f0 (tracked)
# loss_BC = 9.677085991684782e-5 (tracked)
# cntr = 12000
# loss_FD = -9.920356315708819 (tracked)
# loss_true1 = 0.017881276f0 (tracked)
# loss_BC = 0.0001543190244954632 (tracked)
# cntr = 13000
# loss_FD = -9.834677511272968 (tracked)
# loss_true1 = 0.023346806f0 (tracked)
# loss_BC = 0.0002564520129526318 (tracked)
# cntr = 14000
# loss_FD = -10.21069725102533 (tracked)
# loss_true1 = 0.008462686f0 (tracked)
# loss_BC = 5.228289800632032e-5 (tracked)
# cntr = 15000
# loss_FD = -12.021562625746391 (tracked)
# loss_true1 = 0.03025672f0 (tracked)
# loss_BC = 0.0004970810290846893 (tracked)
# cntr = 16000
# loss_FD = -10.943298374768803 (tracked)
# loss_true1 = 0.012609798f0 (tracked)
# loss_BC = 2.9533246417359435e-5 (tracked)
# cntr = 17000
# loss_FD = -9.98449906584425 (tracked)
# loss_true1 = 0.017463729f0 (tracked)
# loss_BC = 4.7792990034593924e-5 (tracked)
# cntr = 18000
# loss_FD = -9.965634182663754 (tracked)
# loss_true1 = 0.032987177f0 (tracked)
# loss_BC = 3.392786283573975e-5 (tracked)
# cntr = 19000
# loss_FD = -9.607391336606351 (tracked)
# loss_true1 = 0.015392944f0 (tracked)
# loss_BC = 4.4220190435348995e-5 (tracked)
# cntr = 20000
# loss_FD = -10.545942855391027 (tracked)
# loss_true1 = 0.014968518f0 (tracked)
# loss_BC = 0.0001342471263029447 (tracked)
# cntr = 21000
# loss_FD = -8.783586191699584 (tracked)
# loss_true1 = 0.015241268f0 (tracked)
# loss_BC = 0.0002704266253075094 (tracked)
# cntr = 22000
# loss_FD = -10.60476058529241 (tracked)
# loss_true1 = 0.006755655f0 (tracked)
# loss_BC = 7.256988265189639e-5 (tracked)
# cntr = 23000
# loss_FD = -9.394131071621462 (tracked)
# loss_true1 = 0.019190527f0 (tracked)
# loss_BC = 5.979888234925614e-5 (tracked)
# cntr = 24000
# loss_FD = -8.354336958115457 (tracked)
# loss_true1 = 0.029723937f0 (tracked)
# loss_BC = 4.0708226274192556e-5 (tracked)
# cntr = 25000
# loss_FD = -11.234282084298723 (tracked)
# loss_true1 = 0.023839302f0 (tracked)
# loss_BC = 8.709750251655301e-5 (tracked)
# cntr = 26000
# loss_FD = -9.641477674724316 (tracked)
# loss_true1 = 0.00838388f0 (tracked)
# loss_BC = 1.619668936274931e-5 (tracked)
# cntr = 27000
# loss_FD = -10.715403664944935 (tracked)
# loss_true1 = 0.010435427f0 (tracked)
# loss_BC = 0.00016048591582034 (tracked)
# cntr = 28000
# loss_FD = -10.041692065793832 (tracked)
# loss_true1 = 0.0062782443f0 (tracked)
# loss_BC = 0.0001767338165824587 (tracked)
# cntr = 29000
# loss_FD = -9.048089994289692 (tracked)
# loss_true1 = 0.034002293f0 (tracked)
# loss_BC = 0.00010258787154101998 (tracked)
# cntr = 30000
# loss_FD = -9.49448840110955 (tracked)
# loss_true1 = 0.020087928f0 (tracked)
# loss_BC = 0.0005692023246942378 (tracked)
# cntr = 31000
# loss_FD = -10.029679278008153 (tracked)
# loss_true1 = 0.03530808f0 (tracked)
# loss_BC = 1.6056215314095638e-5 (tracked)
# cntr = 32000
# loss_FD = -9.03024057432878 (tracked)
# loss_true1 = 0.008527895f0 (tracked)
# loss_BC = 0.0002247395560724794 (tracked)
# cntr = 33000
# loss_FD = -8.414202228298178 (tracked)
# loss_true1 = 0.018796707f0 (tracked)
# loss_BC = 0.00013264072575126714 (tracked)
# cntr = 34000
# loss_FD = -9.540843298994972 (tracked)
# loss_true1 = 0.012290847f0 (tracked)
# loss_BC = 6.947638568277265e-5 (tracked)
# cntr = 35000
# loss_FD = -10.385948470427012 (tracked)
# loss_true1 = 0.005154199f0 (tracked)
# loss_BC = 9.885928840049014e-5 (tracked)
# cntr = 36000
# loss_FD = -11.305448336854685 (tracked)
# loss_true1 = 0.017081305f0 (tracked)
# loss_BC = 0.0002040707666428739 (tracked)
# cntr = 37000
# loss_FD = -9.663667508780373 (tracked)
# loss_true1 = 0.020748304f0 (tracked)
# loss_BC = 6.996866703182358e-5 (tracked)
# cntr = 38000
# loss_FD = -9.389915405301235 (tracked)
# loss_true1 = 0.0035448484f0 (tracked)
# loss_BC = 2.9220782351364422e-5 (tracked)
# cntr = 39000
# loss_FD = -9.023422356777122 (tracked)
# loss_true1 = 0.011190416f0 (tracked)
# loss_BC = 0.00010008620998987482 (tracked)
# cntr = 40000
# loss_FD = -10.29492808859961 (tracked)
# loss_true1 = 0.016011147f0 (tracked)
# loss_BC = 0.00011876883198413592 (tracked)
# cntr = 41000
# loss_FD = -9.986132367638543 (tracked)
# loss_true1 = 0.0448722f0 (tracked)
# loss_BC = 5.011195803035445e-5 (tracked)
# cntr = 42000
# loss_FD = -10.650448003053626 (tracked)
# loss_true1 = 0.0050634923f0 (tracked)
# loss_BC = 0.00012654676043744538 (tracked)
# cntr = 43000
# loss_FD = -10.984023907818562 (tracked)
# loss_true1 = 0.010861771f0 (tracked)
# loss_BC = 1.782249192945728e-5 (tracked)
# cntr = 44000
# loss_FD = -10.429343958410408 (tracked)
# loss_true1 = 0.011486388f0 (tracked)
# loss_BC = 6.323940307282715e-5 (tracked)
# cntr = 45000
# loss_FD = -9.875996717849791 (tracked)
# loss_true1 = 0.016168172f0 (tracked)
# loss_BC = 0.0002413156096607039 (tracked)
# cntr = 46000
# loss_FD = -9.452900210628336 (tracked)
# loss_true1 = 0.008258273f0 (tracked)
# loss_BC = 8.776873146761332e-5 (tracked)
# cntr = 47000
# loss_FD = -9.667271113395508 (tracked)
# loss_true1 = 0.008144136f0 (tracked)
# loss_BC = 1.9761103426990262e-5 (tracked)
# cntr = 48000
# loss_FD = -9.632729824241414 (tracked)
# loss_true1 = 0.010416334f0 (tracked)
# loss_BC = 0.0001056250464724442 (tracked)
# cntr = 49000
# loss_FD = -10.054977023023493 (tracked)
# loss_true1 = 0.014303944f0 (tracked)
# loss_BC = 2.939608773567753e-5 (tracked)
# cntr = 50000
# loss_FD = -10.677766522736764 (tracked)
# loss_true1 = 0.015389544f0 (tracked)
# loss_BC = 3.5478105439779095e-5 (tracked)
# cntr = 51000
# loss_FD = -10.438802178886332 (tracked)
# loss_true1 = 0.016695311f0 (tracked)
# loss_BC = 0.00014660691088165734 (tracked)
# cntr = 52000
# loss_FD = -7.223284115119684 (tracked)
# loss_true1 = 0.014698558f0 (tracked)
# loss_BC = 6.146988575670112e-5 (tracked)
# cntr = 53000
# loss_FD = -11.595694741773446 (tracked)
# loss_true1 = 0.021340575f0 (tracked)
# loss_BC = 0.0002747163430324614 (tracked)
# cntr = 54000
# loss_FD = -9.46710414336842 (tracked)
# loss_true1 = 0.029590916f0 (tracked)
# loss_BC = 3.6948547282867915e-5 (tracked)
# cntr = 55000
# loss_FD = -11.325103059499137 (tracked)
# loss_true1 = 0.018992256f0 (tracked)
# loss_BC = 1.5743823620816444e-5 (tracked)
# cntr = 56000
# loss_FD = -9.834160690336912 (tracked)
# loss_true1 = 0.015208453f0 (tracked)
# loss_BC = 4.70754305035064e-5 (tracked)
# cntr = 57000
# loss_FD = -9.670886751221452 (tracked)
# loss_true1 = 0.008677562f0 (tracked)
# loss_BC = 3.6932702393569785e-5 (tracked)
# cntr = 58000
# loss_FD = -9.419269444885092 (tracked)
# loss_true1 = 0.0049172365f0 (tracked)
# loss_BC = 4.0970637677050414e-5 (tracked)
# cntr = 59000
# loss_FD = -8.752575402859119 (tracked)
# loss_true1 = 0.0060402653f0 (tracked)
# loss_BC = 5.2635285178875265e-5 (tracked)
# cntr = 60000
# loss_FD = -10.908514716352016 (tracked)
# loss_true1 = 0.015034025f0 (tracked)
# loss_BC = 0.0002286160111658846 (tracked)
# cntr = 61000
# loss_FD = -9.91936236968865 (tracked)
# loss_true1 = 0.020418366f0 (tracked)
# loss_BC = 0.00015521546911468885 (tracked)
# cntr = 62000
# loss_FD = -9.487326649894014 (tracked)
# loss_true1 = 0.0045723235f0 (tracked)
# loss_BC = 1.0319172992416076e-5 (tracked)
# cntr = 63000
# loss_FD = -10.40673703475007 (tracked)
# loss_true1 = 0.012698078f0 (tracked)
# loss_BC = 0.0001535366011780132 (tracked)
# cntr = 64000
# loss_FD = -9.40090087686984 (tracked)
# loss_true1 = 0.011866816f0 (tracked)
# loss_BC = 0.00014865396161064203 (tracked)
# cntr = 65000
# loss_FD = -9.382210044035542 (tracked)
# loss_true1 = 0.01333069f0 (tracked)
# loss_BC = 0.00021534183804249193 (tracked)
# cntr = 66000
# loss_FD = -10.850622877216619 (tracked)
# loss_true1 = 0.021445824f0 (tracked)
# loss_BC = 5.4829486514155046e-5 (tracked)
# cntr = 67000
# loss_FD = -9.251092158068126 (tracked)
# loss_true1 = 0.017054524f0 (tracked)
# loss_BC = 0.00011193532392311772 (tracked)
# cntr = 68000
# loss_FD = -9.327337815566564 (tracked)
# loss_true1 = 0.015007591f0 (tracked)
# loss_BC = 0.0001499149542410037 (tracked)
# cntr = 69000
# loss_FD = -9.502114439798753 (tracked)
# loss_true1 = 0.01180814f0 (tracked)
# loss_BC = 3.686683654650436e-5 (tracked)
# cntr = 70000
# loss_FD = -10.096282522211053 (tracked)
# loss_true1 = 0.025239838f0 (tracked)
# loss_BC = 2.3635693417927163e-5 (tracked)
# cntr = 71000
# loss_FD = -9.179754390760763 (tracked)
# loss_true1 = 0.030674934f0 (tracked)
# loss_BC = 7.647323955008677e-5 (tracked)
# cntr = 72000
# loss_FD = -10.979677719458438 (tracked)
# loss_true1 = 0.010043709f0 (tracked)
# loss_BC = 0.00012232303048055864 (tracked)
# cntr = 73000
# loss_FD = -9.82495598088904 (tracked)
# loss_true1 = 0.022073498f0 (tracked)
# loss_BC = 0.00011226640554722258 (tracked)
# cntr = 74000
# loss_FD = -9.139488118648632 (tracked)
# loss_true1 = 0.013821351f0 (tracked)
# loss_BC = 7.920012637868607e-5 (tracked)
# cntr = 75000
# loss_FD = -9.088236022629943 (tracked)
# loss_true1 = 0.01721331f0 (tracked)
# loss_BC = 8.642853270358209e-5 (tracked)
# cntr = 76000
# loss_FD = -10.368805674158807 (tracked)
# loss_true1 = 0.02309503f0 (tracked)
# loss_BC = 0.0002715781447776877 (tracked)
# cntr = 77000
# loss_FD = -10.772771832866592 (tracked)
# loss_true1 = 0.011741152f0 (tracked)
# loss_BC = 7.380070772407294e-5 (tracked)
# cntr = 78000
# loss_FD = -9.868791121232231 (tracked)
# loss_true1 = 0.007263822f0 (tracked)
# loss_BC = 7.934254720291621e-5 (tracked)
