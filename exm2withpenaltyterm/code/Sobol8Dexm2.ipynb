# %%
using Flux.Tracker
using Flux
using Flux:throttle,glorot_uniform
using BSON:@save
using BSON:@load
using Base.Iterators: repeated
using Flux:@treelike
using PyPlot
using FastGaussQuadrature
using SparseGrids
using LinearAlgebra
using Flux: @epochs
using DataFrames
using CSV
using Sobol
using Pkg; Pkg.activate("cuda"); Pkg.instantiate()
using CuArrays
using ForwardDiff
using CUDAnative
CuArrays.culiteral_pow(::typeof(^), x::ForwardDiff.Dual{Nothing,Float32,1}, ::Val{2}) = x*x
CuArrays.culiteral_pow(::typeof(^), x::ForwardDiff.Dual{Nothing,Float64,1}, ::Val{2}) = x*x

f(x)=2*π^2 .*sum(cos.(π*x[i,:]') for i=1:8, dims=1)
acti(x)=@. x/(1+CUDAnative.exp(-x))


struct Block{F,S,T}
  W1::S
  W2::S
  b1::T
  b2::T
  σ::F
end

Block(W1 , W2, b1, b2) = Block(W1,W2 ,b1 ,b2, identity)

function Block(in1::Integer,in2::Integer, out1::Integer,out2::Integer, σ = identity;
  initW1 = glorot_uniform, initW2 =glorot_uniform, initb1 = zeros,initb2=zeros)
  return Block(param(initW1(out1, in1)),param(initW2(out2,in2)), param(initb1(out1)), param(initb2(out2)),σ)
end

@treelike Block

function (a::Block)(x)
  W1,W2, b1,b2, σ = a.W1,a.W2,a.b1, a.b2, a.σ
  σ.(W2 *σ.(W1*x .+ b1) .+ b2) .+ x
end





M=Chain(
Dense(8,30),
Block(30,30,30,30,acti),
Block(30,30,30,30,acti),
Block(30,30,30,30,acti),
Block(30,30,30,30,acti),
Dense(30,1)
)|>gpu

#=
@load "test1FD.bson" M
@load "test2FD.bson" weights
Flux.loadparams!(M, weights)
=#


#=

function loss(s,y=1)
  loss = sum((M(s) - 0.25*(s[1,:].^2+s[2,:].^2 .-1)').^2)
  return loss
end
=#

function lossFD(N)
  notes=zeros(8,N)
  for i=1:N
    notes[:,i]=next!(inner)
  end
  notes =notes |>gpu
  d=rand(1)/100 |>gpu
  losses=0
  MMM=M(notes)
  for i=1:8
    l1=zeros(8)
    l1[i]=1
    l1 = l1 |>gpu
    losses  += (sum(0.5*((M(notes .+ d.*l1) .- MMM)./d).^2)/N)[1]
  end
  losses += (sum(0.5*(π^2 * (MMM).^2))/N)[1]
  losses += (sum(-f(notes) .*MMM)/N)[1]
  return losses
end

function lossBC(β)
  d=(rand(1)/100)|>gpu
  point=zeros(8,1600)
  p=zeros(7,100)
  for i=1:100
    p[:,i]=next!(BC)
  end
  for i=1:8
    point[:,200*(i-1)+1:200*(i-1)+100]=vcat(p[1:i-1,:],zeros(100)',p[i:end,:])
    point[:,200*(i-1)+101:200*i]=vcat(p[1:i-1,:], ones(100)',p[i:end,:])
  end
    point=point|>gpu
  losses=0
  for i=1:8
    l2=zeros(8)
    l1=zeros(8)
    l2[i]=2
    l1[i]=1
    l1=l1|>gpu
    l2=l2|>gpu
    losses +=β*(sum((( 1/2*M(point[:,200*(i-1)+1:200*i] .+ d.*l1) .- 1/2*M(point[:,200*(i-1)+1:200*i] .- d.*l1))./d).^2)/100)[1]
  end
  return losses
end

function loss1(N)
  return lossBC(50)+lossFD(N)
end



function loss_true(xx=1,yy=1,xx1=1,xx2=2)
  points=zeros(8,5000)
    for i=1:5000
      points[:,i]=next!(truep)
    end
    points=points  |>gpu
  F_true(x)= sum(cos.(pi*x[i,:]') for i=1:8, dims=1)
  errors=sqrt(sum((M(points)-F_true(points)).^2)/2000)
  return errors
end
truep=SobolSeq(8)

inner=SobolSeq(8)
BC=SobolSeq(7)
function test(N;traintime=2000)
  errdf=DataFrame(time=Int[],absolute_error=Float64[],loss_FD=Float64[])
  cntr=1
  evalcb = function()
    loss_true1=loss_true()
    loss_FD = lossFD(N)
    push!(errdf,[Tracker.data(cntr),Tracker.data(loss_true1),Tracker.data(loss_FD)])
    cntr+=1
    if cntr%500==0
      @show(cntr,loss_FD,loss_true1)
      CSV.write("$(N)Sobol8Dexm2.csv",errdf)
      @save "$(N)Sobolpoint8Dexm2m.bson" M
      weights=Tracker.data.(params(M))
      @save "$(N)Sobolpoint8Dexm2w.bson" weights
    end
  end
  θ=Flux.params(M)
  opt=ADAM()
  dataset=[(N) for i=1:traintime]
  Flux.train!(loss1, params(M), zip(dataset), opt, cb=evalcb)
  return errdf
end
# Out:
# Activating new environment at `~/exm2/cuda/Project.toml`
#   Updating registry at `~/.julia/registries/General`
#   Updating git-repo `https://github.com/JuliaRegistries/General.git`
#  Resolving package versions...
# test (generic function with 1 method)

# %%
errdf=test(100,traintime=50000)
for i=1:4
    N=[500 1000 2000 10000]
    errdf=test(N[i],traintime=20000)
end
# Out:
# cntr = 500
# loss_FD = -1.2521597459485652 (tracked)
# loss_true1 = 3.1087825f0 (tracked)
# cntr = 1000
# loss_FD = -14.084606125098937 (tracked)
# loss_true1 = 2.5380523f0 (tracked)
# cntr = 1500
# loss_FD = -26.63269239455864 (tracked)
# loss_true1 = 1.588723f0 (tracked)
# cntr = 2000
# loss_FD = -32.58551398775146 (tracked)
# loss_true1 = 1.467154f0 (tracked)
# cntr = 2500
# loss_FD = -37.60506623301963 (tracked)
# loss_true1 = 1.0906321f0 (tracked)
# cntr = 3000
# loss_FD = -38.44732586646599 (tracked)
# loss_true1 = 0.80061495f0 (tracked)
# cntr = 3500
# loss_FD = -40.48010410588239 (tracked)
# loss_true1 = 0.19731796f0 (tracked)
# cntr = 4000
# loss_FD = -38.052154361669864 (tracked)
# loss_true1 = 0.15191132f0 (tracked)
# cntr = 4500
# loss_FD = -39.5481588721866 (tracked)
# loss_true1 = 0.1280506f0 (tracked)
# cntr = 5000
# loss_FD = -39.209583357782876 (tracked)
# loss_true1 = 0.13242835f0 (tracked)
# cntr = 5500
# loss_FD = -38.69811539801696 (tracked)
# loss_true1 = 0.12648755f0 (tracked)
# cntr = 6000
# loss_FD = -16.270090249693173 (tracked)
# loss_true1 = 2.375337f0 (tracked)
# cntr = 6500
# loss_FD = -32.76469726553202 (tracked)
# loss_true1 = 1.4990996f0 (tracked)
# cntr = 7000
# loss_FD = -38.24665255656212 (tracked)
# loss_true1 = 0.5464099f0 (tracked)
# cntr = 7500
# loss_FD = -39.42958567054187 (tracked)
# loss_true1 = 0.2958332f0 (tracked)
# cntr = 8000
# loss_FD = -38.269459032497295 (tracked)
# loss_true1 = 0.2234046f0 (tracked)
# cntr = 8500
# loss_FD = -44.701034777343914 (tracked)
# loss_true1 = 0.18628192f0 (tracked)
# cntr = 9000
# loss_FD = -40.27080585554667 (tracked)
# loss_true1 = 0.15755033f0 (tracked)
# cntr = 9500
# loss_FD = -46.194771753768784 (tracked)
# loss_true1 = 0.13535291f0 (tracked)
# cntr = 10000
# loss_FD = -41.101956805783615 (tracked)
# loss_true1 = 0.124328904f0 (tracked)
# cntr = 10500
# loss_FD = -40.24339088348512 (tracked)
# loss_true1 = 0.10596522f0 (tracked)
# cntr = 11000
# loss_FD = -44.03817805398596 (tracked)
# loss_true1 = 0.10120257f0 (tracked)
# cntr = 11500
# loss_FD = -37.931380323197956 (tracked)
# loss_true1 = 0.08692144f0 (tracked)
# cntr = 12000
# loss_FD = -35.14124712682576 (tracked)
# loss_true1 = 0.08067502f0 (tracked)
# cntr = 12500
# loss_FD = -36.02169585652273 (tracked)
# loss_true1 = 0.076556206f0 (tracked)
# cntr = 13000
# loss_FD = -41.31146838577686 (tracked)
# loss_true1 = 0.08084571f0 (tracked)
# cntr = 13500
# loss_FD = -39.35446993834033 (tracked)
# loss_true1 = 0.50871766f0 (tracked)
# cntr = 14000
# loss_FD = -40.014949789894416 (tracked)
# loss_true1 = 0.18398948f0 (tracked)
# cntr = 14500
# loss_FD = -36.846406800364576 (tracked)
# loss_true1 = 0.13580608f0 (tracked)
# cntr = 15000
# loss_FD = -36.73180775360906 (tracked)
# loss_true1 = 0.12777081f0 (tracked)
# cntr = 15500
# loss_FD = -39.75710834056387 (tracked)
# loss_true1 = 0.11595848f0 (tracked)
# cntr = 16000
# loss_FD = -43.67422649714962 (tracked)
# loss_true1 = 0.1051057f0 (tracked)
# cntr = 16500
# loss_FD = -35.678680393382805 (tracked)
# loss_true1 = 0.08459416f0 (tracked)
# cntr = 17000
# loss_FD = -36.27683074976319 (tracked)
# loss_true1 = 0.08358568f0 (tracked)
# cntr = 17500
# loss_FD = -40.47014515138327 (tracked)
# loss_true1 = 0.080905f0 (tracked)
# cntr = 18000
# loss_FD = -42.2107042261986 (tracked)
# loss_true1 = 0.081169814f0 (tracked)
# cntr = 18500
# loss_FD = -34.97754077843643 (tracked)
# loss_true1 = 0.071852535f0 (tracked)
# cntr = 19000
# loss_FD = -38.30438917154568 (tracked)
# loss_true1 = 0.076253526f0 (tracked)
# cntr = 19500
# loss_FD = -37.581975584724916 (tracked)
# loss_true1 = 0.06434173f0 (tracked)
# cntr = 20000
# loss_FD = -36.976561505632375 (tracked)
# loss_true1 = 0.0637062f0 (tracked)
# cntr = 20500
# loss_FD = -40.24048783775865 (tracked)
# loss_true1 = 0.0602134f0 (tracked)
# cntr = 21000
# loss_FD = -44.75410420115974 (tracked)
# loss_true1 = 0.059146162f0 (tracked)
# cntr = 21500
# loss_FD = -38.9367848065507 (tracked)
# loss_true1 = 0.060174827f0 (tracked)
# cntr = 22000
# loss_FD = -42.937932394499505 (tracked)
# loss_true1 = 0.070640214f0 (tracked)
# cntr = 22500
# loss_FD = -40.35290899243339 (tracked)
# loss_true1 = 0.070382915f0 (tracked)
# cntr = 23000
# loss_FD = -39.830729165474544 (tracked)
# loss_true1 = 0.060950454f0 (tracked)
# cntr = 23500
# loss_FD = -41.70839107086062 (tracked)
# loss_true1 = 0.0683804f0 (tracked)
# cntr = 24000
# loss_FD = -38.023876727119045 (tracked)
# loss_true1 = 0.05303008f0 (tracked)
# cntr = 24500
# loss_FD = -36.28614991855281 (tracked)
# loss_true1 = 0.05135227f0 (tracked)
# cntr = 25000
# loss_FD = -33.86563789770483 (tracked)
# loss_true1 = 0.05083609f0 (tracked)
# cntr = 25500
# loss_FD = -37.78648523316918 (tracked)
# loss_true1 = 0.048121918f0 (tracked)
# cntr = 26000
# loss_FD = -40.214764417605785 (tracked)
# loss_true1 = 0.05501607f0 (tracked)
# cntr = 26500
# loss_FD = -41.15269023393539 (tracked)
# loss_true1 = 0.052071616f0 (tracked)
# cntr = 27000
# loss_FD = -44.52619020806583 (tracked)
# loss_true1 = 0.048066236f0 (tracked)
# cntr = 27500
# loss_FD = -38.261530684500016 (tracked)
# loss_true1 = 0.040576283f0 (tracked)
# cntr = 28000
# loss_FD = -39.8635338351432 (tracked)
# loss_true1 = 0.14185767f0 (tracked)
# cntr = 28500
# loss_FD = -41.08844461605008 (tracked)
# loss_true1 = 0.084481895f0 (tracked)
# cntr = 29000
# loss_FD = -33.96053480757482 (tracked)
# loss_true1 = 0.07233002f0 (tracked)
# cntr = 29500
# loss_FD = -41.088181058916604 (tracked)
# loss_true1 = 0.0607692f0 (tracked)
# cntr = 30000
# loss_FD = -37.06603063027386 (tracked)
# loss_true1 = 0.05407455f0 (tracked)
# cntr = 30500
# loss_FD = -38.052968156968824 (tracked)
# loss_true1 = 0.6390581f0 (tracked)
# cntr = 31000
# loss_FD = -35.564217001035004 (tracked)
# loss_true1 = 0.062409066f0 (tracked)
# cntr = 31500
# loss_FD = -41.37514478317702 (tracked)
# loss_true1 = 0.05385169f0 (tracked)
# cntr = 32000
# loss_FD = -41.72074916036609 (tracked)
# loss_true1 = 0.050161466f0 (tracked)
# cntr = 32500
# loss_FD = -42.35782700655537 (tracked)
# loss_true1 = 0.051676955f0 (tracked)
# cntr = 33000
# loss_FD = -45.3947117709635 (tracked)
# loss_true1 = 0.045970388f0 (tracked)
# cntr = 33500
# loss_FD = -40.452678393567126 (tracked)
# loss_true1 = 0.067736186f0 (tracked)
# cntr = 34000
# loss_FD = -40.309823491122586 (tracked)
# loss_true1 = 0.054025017f0 (tracked)
# cntr = 34500
# loss_FD = -38.40946464422973 (tracked)
# loss_true1 = 0.06900713f0 (tracked)
# cntr = 35000
# loss_FD = -39.8935701217726 (tracked)
# loss_true1 = 0.07935478f0 (tracked)
# cntr = 35500
# loss_FD = -42.72286276232839 (tracked)
# loss_true1 = 0.04819824f0 (tracked)
# cntr = 36000
# loss_FD = -43.68094385583987 (tracked)
# loss_true1 = 0.06314511f0 (tracked)
# cntr = 36500
# loss_FD = -36.56924915709547 (tracked)
# loss_true1 = 0.06993706f0 (tracked)
# cntr = 37000
# loss_FD = -42.518043306530664 (tracked)
# loss_true1 = 0.055400908f0 (tracked)
# cntr = 37500
# loss_FD = -43.019142863027355 (tracked)
# loss_true1 = 0.047004618f0 (tracked)
# cntr = 38000
# loss_FD = -39.83450885033761 (tracked)
# loss_true1 = 0.05880875f0 (tracked)
# cntr = 38500
# loss_FD = -39.12451411277783 (tracked)
# loss_true1 = 0.07005636f0 (tracked)
# cntr = 39000
# loss_FD = -41.756087994830494 (tracked)
# loss_true1 = 0.05103986f0 (tracked)
# cntr = 39500
# loss_FD = -39.74623215685609 (tracked)
# loss_true1 = 0.05035882f0 (tracked)
# cntr = 40000
# loss_FD = -40.07277991735056 (tracked)
# loss_true1 = 0.04706217f0 (tracked)
# cntr = 40500
# loss_FD = -38.70921581704242 (tracked)
# loss_true1 = 0.04598937f0 (tracked)
# cntr = 41000
# loss_FD = -35.29747718640019 (tracked)
# loss_true1 = 0.079046406f0 (tracked)
# cntr = 41500
# loss_FD = -34.847800539583545 (tracked)
# loss_true1 = 0.054460865f0 (tracked)
# cntr = 42000
# loss_FD = -41.6822284464894 (tracked)
# loss_true1 = 0.050648104f0 (tracked)
# cntr = 42500
# loss_FD = -39.42647045270196 (tracked)
# loss_true1 = 0.05756764f0 (tracked)
# cntr = 43000
# loss_FD = -38.605781747224654 (tracked)
# loss_true1 = 0.06679625f0 (tracked)
# cntr = 43500
# loss_FD = -36.78844151014834 (tracked)
# loss_true1 = 0.05984135f0 (tracked)
# cntr = 44000
# loss_FD = -34.59325095091659 (tracked)
# loss_true1 = 0.061991613f0 (tracked)
# cntr = 44500
# loss_FD = -36.75972586073077 (tracked)
# loss_true1 = 0.06958226f0 (tracked)
# cntr = 45000
# loss_FD = -38.863825141446405 (tracked)
# loss_true1 = 0.06124365f0 (tracked)
# cntr = 45500
# loss_FD = -42.809963030280784 (tracked)
# loss_true1 = 0.051673166f0 (tracked)
# cntr = 46000
# loss_FD = -38.91136645979917 (tracked)
# loss_true1 = 0.04940486f0 (tracked)
# cntr = 46500
# loss_FD = -35.19882767603884 (tracked)
# loss_true1 = 0.04969606f0 (tracked)
# cntr = 47000
# loss_FD = -43.99135803167002 (tracked)
# loss_true1 = 0.049810193f0 (tracked)
# cntr = 47500
# loss_FD = -35.341105672248624 (tracked)
# loss_true1 = 0.05736922f0 (tracked)
# cntr = 48000
# loss_FD = -39.51647656618111 (tracked)
# loss_true1 = 0.030720329f0 (tracked)
# cntr = 48500
# loss_FD = -36.25767896550621 (tracked)
# loss_true1 = 0.029083934f0 (tracked)
# cntr = 49000
# loss_FD = -36.43010672224858 (tracked)
# loss_true1 = 0.052894205f0 (tracked)
# cntr = 49500
# loss_FD = -43.158748633181204 (tracked)
# loss_true1 = 0.046350338f0 (tracked)
# cntr = 50000
# loss_FD = -41.13268401150836 (tracked)
# loss_true1 = 0.03663211f0 (tracked)
# cntr = 500
# loss_FD = -39.462604102616126 (tracked)
# loss_true1 = 0.025822747f0 (tracked)
# cntr = 1000
# loss_FD = -40.39840048824662 (tracked)
# loss_true1 = 0.027199639f0 (tracked)
# cntr = 1500
# loss_FD = -39.94950433013162 (tracked)
# loss_true1 = 0.024186525f0 (tracked)
# cntr = 2000
# loss_FD = -38.30208606064873 (tracked)
# loss_true1 = 0.028570598f0 (tracked)
# cntr = 2500
# loss_FD = -39.42163479187466 (tracked)
# loss_true1 = 0.02413998f0 (tracked)
# cntr = 3000
# loss_FD = -39.73061888319904 (tracked)
# loss_true1 = 0.028218668f0 (tracked)
# cntr = 3500
# loss_FD = -39.44654091342496 (tracked)
# loss_true1 = 0.023889132f0 (tracked)
# cntr = 4000
# loss_FD = -39.339641793562194 (tracked)
# loss_true1 = 0.02488694f0 (tracked)
# cntr = 4500
# loss_FD = -38.791152910226316 (tracked)
# loss_true1 = 0.02313895f0 (tracked)
# cntr = 5000
# loss_FD = -38.966433109570914 (tracked)
# loss_true1 = 0.024350947f0 (tracked)
# cntr = 5500
# loss_FD = -39.8166321006842 (tracked)
# loss_true1 = 0.024784384f0 (tracked)
# cntr = 6000
# loss_FD = -40.29273258299063 (tracked)
# loss_true1 = 0.025457393f0 (tracked)
# cntr = 6500
# loss_FD = -39.64519334745873 (tracked)
# loss_true1 = 0.0324604f0 (tracked)
# cntr = 7000
# loss_FD = -39.62830244743728 (tracked)
# loss_true1 = 0.03186319f0 (tracked)
# cntr = 7500
# loss_FD = -39.562973431675694 (tracked)
# loss_true1 = 0.028661748f0 (tracked)
# cntr = 8000
# loss_FD = -39.442253956743556 (tracked)
# loss_true1 = 0.03239586f0 (tracked)
# cntr = 8500
# loss_FD = -39.58755554384392 (tracked)
# loss_true1 = 0.02475511f0 (tracked)
# cntr = 9000
# loss_FD = -39.51734871816868 (tracked)
# loss_true1 = 0.025066841f0 (tracked)
# cntr = 9500
# loss_FD = -40.01219625059341 (tracked)
# loss_true1 = 0.024428573f0 (tracked)
# cntr = 10000
# loss_FD = -40.208637366876594 (tracked)
# loss_true1 = 0.026881728f0 (tracked)
# cntr = 10500
# loss_FD = -40.672829106005466 (tracked)
# loss_true1 = 0.025607942f0 (tracked)
# cntr = 11000
# loss_FD = -39.3153074397961 (tracked)
# loss_true1 = 0.025599737f0 (tracked)
# cntr = 11500
# loss_FD = -40.13612686449656 (tracked)
# loss_true1 = 0.021705834f0 (tracked)
# cntr = 12000
# loss_FD = -40.54180995350424 (tracked)
# loss_true1 = 0.024847245f0 (tracked)
# cntr = 12500
# loss_FD = -38.77718406502923 (tracked)
# loss_true1 = 0.024711324f0 (tracked)
# cntr = 13000
# loss_FD = -40.04485198602659 (tracked)
# loss_true1 = 0.022781553f0 (tracked)
# cntr = 13500
# loss_FD = -38.88655053824091 (tracked)
# loss_true1 = 0.021382084f0 (tracked)
# cntr = 14000
# loss_FD = -40.54299178692223 (tracked)
# loss_true1 = 0.02290424f0 (tracked)
# cntr = 14500
# loss_FD = -39.05672641547814 (tracked)
# loss_true1 = 0.02364617f0 (tracked)
# cntr = 15000
# loss_FD = -39.375246481121785 (tracked)
# loss_true1 = 0.02432118f0 (tracked)
# cntr = 15500
# loss_FD = -40.0303779052099 (tracked)
# loss_true1 = 0.020632427f0 (tracked)
# cntr = 16000
# loss_FD = -39.28157484055443 (tracked)
# loss_true1 = 0.027408363f0 (tracked)
# cntr = 16500
# loss_FD = -39.57560362237903 (tracked)
# loss_true1 = 0.021794269f0 (tracked)
# cntr = 17000
# loss_FD = -40.971493863079345 (tracked)
# loss_true1 = 0.023472972f0 (tracked)
# cntr = 17500
# loss_FD = -39.92609516460513 (tracked)
# loss_true1 = 0.02639422f0 (tracked)
# cntr = 18000
# loss_FD = -40.35739560091241 (tracked)
# loss_true1 = 0.026304085f0 (tracked)
# cntr = 18500
# loss_FD = -39.50036797238339 (tracked)
# loss_true1 = 0.020775264f0 (tracked)
# cntr = 19000
# loss_FD = -40.27910750538213 (tracked)
# loss_true1 = 0.019192612f0 (tracked)
# cntr = 19500
# loss_FD = -39.23186022598319 (tracked)
# loss_true1 = 0.024593806f0 (tracked)
# cntr = 20000
# loss_FD = -40.23022034018432 (tracked)
# loss_true1 = 0.024469387f0 (tracked)
# cntr = 500
# loss_FD = -39.76303673778257 (tracked)
# loss_true1 = 0.019716134f0 (tracked)
# cntr = 1000
# loss_FD = -39.21796861536697 (tracked)
# loss_true1 = 0.020633193f0 (tracked)
# cntr = 1500
# loss_FD = -39.7670882142395 (tracked)
# loss_true1 = 0.01982746f0 (tracked)
# cntr = 2000
# loss_FD = -39.483418276913554 (tracked)
# loss_true1 = 0.01864344f0 (tracked)
# cntr = 2500
# loss_FD = -39.26241994416041 (tracked)
# loss_true1 = 0.021465827f0 (tracked)
# cntr = 3000
# loss_FD = -39.48980607226284 (tracked)
# loss_true1 = 0.097294725f0 (tracked)
# cntr = 3500
# loss_FD = -39.19411507986892 (tracked)
# loss_true1 = 0.018117072f0 (tracked)
# cntr = 4000
# loss_FD = -39.211873932104396 (tracked)
# loss_true1 = 0.018885644f0 (tracked)
# cntr = 4500
# loss_FD = -39.09316922294558 (tracked)
# loss_true1 = 0.01756805f0 (tracked)
# cntr = 5000
# loss_FD = -39.307305016854954 (tracked)
# loss_true1 = 0.023074847f0 (tracked)
# cntr = 5500
# loss_FD = -38.955060245487104 (tracked)
# loss_true1 = 0.02044297f0 (tracked)
# cntr = 6000
# loss_FD = -39.33435740649398 (tracked)
# loss_true1 = 0.02003583f0 (tracked)
# cntr = 6500
# loss_FD = -39.57231207199594 (tracked)
# loss_true1 = 0.020865958f0 (tracked)
# cntr = 7000
# loss_FD = -40.277323795960534 (tracked)
# loss_true1 = 0.018823681f0 (tracked)
# cntr = 7500
# loss_FD = -39.31512930260483 (tracked)
# loss_true1 = 0.020580875f0 (tracked)
# cntr = 8000
# loss_FD = -39.769875014390784 (tracked)
# loss_true1 = 0.017545454f0 (tracked)
# cntr = 8500
# loss_FD = -39.23022301975843 (tracked)
# loss_true1 = 0.017017908f0 (tracked)
# cntr = 9000
# loss_FD = -39.76208565329185 (tracked)
# loss_true1 = 0.018043827f0 (tracked)
# cntr = 9500
# loss_FD = -38.354296530413336 (tracked)
# loss_true1 = 0.017727314f0 (tracked)
# cntr = 10000
# loss_FD = -39.62196257088529 (tracked)
# loss_true1 = 0.024851669f0 (tracked)
# cntr = 10500
# loss_FD = -39.510309048213294 (tracked)
# loss_true1 = 0.020008745f0 (tracked)
# cntr = 11000
# loss_FD = -39.79194925302716 (tracked)
# loss_true1 = 0.017812349f0 (tracked)
# cntr = 11500
# loss_FD = -39.24478869819117 (tracked)
# loss_true1 = 0.019062255f0 (tracked)
# cntr = 12000
# loss_FD = -39.45857075782579 (tracked)
# loss_true1 = 0.017478561f0 (tracked)
# cntr = 12500
# loss_FD = -39.720453424754524 (tracked)
# loss_true1 = 0.017929442f0 (tracked)
# cntr = 13000
# loss_FD = -39.826560949665804 (tracked)
# loss_true1 = 0.015464884f0 (tracked)
# cntr = 13500
# loss_FD = -39.42474148364521 (tracked)
# loss_true1 = 0.017292159f0 (tracked)
# cntr = 14000
# loss_FD = -38.974197581132096 (tracked)
# loss_true1 = 0.015886966f0 (tracked)
# cntr = 14500
# loss_FD = -39.80898401660726 (tracked)
# loss_true1 = 0.019448271f0 (tracked)
# cntr = 15000
# loss_FD = -39.726708399095855 (tracked)
# loss_true1 = 0.020263216f0 (tracked)
# cntr = 15500
# loss_FD = -38.97300509471471 (tracked)
# loss_true1 = 0.021223543f0 (tracked)
# cntr = 16000
# loss_FD = -40.21678529561838 (tracked)
# loss_true1 = 0.017627433f0 (tracked)
# cntr = 16500
# loss_FD = -39.37622595339228 (tracked)
# loss_true1 = 0.018618777f0 (tracked)
# cntr = 17000
# loss_FD = -39.991027522889226 (tracked)
# loss_true1 = 0.018831532f0 (tracked)
# cntr = 17500
# loss_FD = -39.01463682432025 (tracked)
# loss_true1 = 0.017292354f0 (tracked)
# cntr = 18000
# loss_FD = -39.34052934626795 (tracked)
# loss_true1 = 0.018471701f0 (tracked)
# cntr = 18500
# loss_FD = -40.14018068584522 (tracked)
# loss_true1 = 0.016685046f0 (tracked)
# cntr = 19000
# loss_FD = -39.52807372696894 (tracked)
# loss_true1 = 0.021188144f0 (tracked)
# cntr = 19500
# loss_FD = -39.95214950195859 (tracked)
# loss_true1 = 0.018067218f0 (tracked)
# cntr = 20000
# loss_FD = -39.3599776456077 (tracked)
# loss_true1 = 0.018191805f0 (tracked)
# cntr = 500
# loss_FD = -39.39549437442008 (tracked)
# loss_true1 = 0.015915466f0 (tracked)
# cntr = 1000
# loss_FD = -39.47581580942115 (tracked)
# loss_true1 = 0.016214617f0 (tracked)
# cntr = 1500
# loss_FD = -39.51198231619073 (tracked)
# loss_true1 = 0.016393568f0 (tracked)
# cntr = 2000
# loss_FD = -39.38905531185018 (tracked)
# loss_true1 = 0.015043789f0 (tracked)
# cntr = 2500
# loss_FD = -39.18372958439414 (tracked)
# loss_true1 = 0.015259263f0 (tracked)
# cntr = 3000
# loss_FD = -39.55851162151846 (tracked)
# loss_true1 = 0.026842454f0 (tracked)
# cntr = 3500
# loss_FD = -39.60449004116862 (tracked)
# loss_true1 = 0.018797502f0 (tracked)
# cntr = 4000
# loss_FD = -39.37678501879231 (tracked)
# loss_true1 = 0.016674247f0 (tracked)
# cntr = 4500
# loss_FD = -39.400668678684184 (tracked)
# loss_true1 = 0.017744467f0 (tracked)
# cntr = 5000
# loss_FD = -39.69342506812495 (tracked)
# loss_true1 = 0.017859627f0 (tracked)
# cntr = 5500
# loss_FD = -39.410875843426886 (tracked)
# loss_true1 = 0.017413378f0 (tracked)
# cntr = 6000
# loss_FD = -39.42192854170191 (tracked)
# loss_true1 = 0.017095588f0 (tracked)
# cntr = 6500
# loss_FD = -39.86679456405062 (tracked)
# loss_true1 = 0.018038535f0 (tracked)
# cntr = 7000
# loss_FD = -39.23831026595291 (tracked)
# loss_true1 = 0.01601497f0 (tracked)
# cntr = 7500
# loss_FD = -39.40370741652148 (tracked)
# loss_true1 = 0.019878082f0 (tracked)
# cntr = 8000
# loss_FD = -39.46352881191068 (tracked)
# loss_true1 = 0.018057322f0 (tracked)
# cntr = 8500
# loss_FD = -39.536655421618846 (tracked)
# loss_true1 = 0.016304981f0 (tracked)
# cntr = 9000
# loss_FD = -39.46515847328742 (tracked)
# loss_true1 = 0.017867018f0 (tracked)
# cntr = 9500
# loss_FD = -39.65974656260608 (tracked)
# loss_true1 = 0.017944165f0 (tracked)
# cntr = 10000
# loss_FD = -39.49179164346273 (tracked)
# loss_true1 = 0.01783922f0 (tracked)
# cntr = 10500
# loss_FD = -39.833851593582835 (tracked)
# loss_true1 = 0.015625594f0 (tracked)
# cntr = 11000
# loss_FD = -39.181008467526055 (tracked)
# loss_true1 = 0.03912832f0 (tracked)
# cntr = 11500
# loss_FD = -39.63729266886584 (tracked)
# loss_true1 = 0.02449132f0 (tracked)
# cntr = 12000
# loss_FD = -39.716816960649396 (tracked)
# loss_true1 = 0.023095842f0 (tracked)
# cntr = 12500
# loss_FD = -39.67976113182586 (tracked)
# loss_true1 = 0.019225415f0 (tracked)
# cntr = 13000
# loss_FD = -39.41815241676884 (tracked)
# loss_true1 = 0.019171849f0 (tracked)
# cntr = 13500
# loss_FD = -39.543451004474775 (tracked)
# loss_true1 = 0.01921279f0 (tracked)
# cntr = 14000
# loss_FD = -39.52368274952204 (tracked)
# loss_true1 = 0.01939153f0 (tracked)
# cntr = 14500
# loss_FD = -39.50202885524638 (tracked)
# loss_true1 = 0.019487258f0 (tracked)
# cntr = 15000
# loss_FD = -39.484294821272265 (tracked)
# loss_true1 = 0.019981733f0 (tracked)
# cntr = 15500
# loss_FD = -39.37274510400789 (tracked)
# loss_true1 = 0.05048129f0 (tracked)
# cntr = 16000
# loss_FD = -39.806153784354535 (tracked)
# loss_true1 = 0.01689288f0 (tracked)
# cntr = 16500
# loss_FD = -39.43732938967241 (tracked)
# loss_true1 = 0.017421491f0 (tracked)
# cntr = 17000
# loss_FD = -39.35044915136318 (tracked)
# loss_true1 = 0.019205593f0 (tracked)
# cntr = 17500
# loss_FD = -39.33312303691034 (tracked)
# loss_true1 = 0.017793648f0 (tracked)
# cntr = 18000
# loss_FD = -39.413074312889584 (tracked)
# loss_true1 = 0.02358563f0 (tracked)
# cntr = 18500
# loss_FD = -39.31151366790414 (tracked)
# loss_true1 = 0.016605217f0 (tracked)
# cntr = 19000
# loss_FD = -39.35769155645755 (tracked)
# loss_true1 = 0.019721324f0 (tracked)
# cntr = 19500
# loss_FD = -39.38881152363149 (tracked)
# loss_true1 = 0.017206188f0 (tracked)
# cntr = 20000
# loss_FD = -39.196624113198865 (tracked)
# loss_true1 = 0.016472803f0 (tracked)
# cntr = 500
# loss_FD = -39.4718420173879 (tracked)
# loss_true1 = 0.016248174f0 (tracked)
# cntr = 1000
# loss_FD = -39.45517706205277 (tracked)
# loss_true1 = 0.018993132f0 (tracked)
# cntr = 1500
# loss_FD = -39.48446545325183 (tracked)
# loss_true1 = 0.015793579f0 (tracked)
# cntr = 2000
# loss_FD = -39.39475125961844 (tracked)
# loss_true1 = 0.01664192f0 (tracked)
# cntr = 2500
# loss_FD = -39.49651552399811 (tracked)
# loss_true1 = 0.016398128f0 (tracked)
# cntr = 3000
# loss_FD = -39.53590594064795 (tracked)
# loss_true1 = 0.017995896f0 (tracked)
# cntr = 3500
# loss_FD = -39.430652297763174 (tracked)
# loss_true1 = 0.01520814f0 (tracked)
# cntr = 4000
# loss_FD = -39.475928094534595 (tracked)
# loss_true1 = 0.017082766f0 (tracked)
# cntr = 4500
# loss_FD = -39.459067517715724 (tracked)
# loss_true1 = 0.015393033f0 (tracked)
# cntr = 5000
# loss_FD = -39.490193558140106 (tracked)
# loss_true1 = 0.01495646f0 (tracked)
# cntr = 5500
# loss_FD = -39.4180685790261 (tracked)
# loss_true1 = 0.015395251f0 (tracked)
# cntr = 6000
# loss_FD = -39.45478924895615 (tracked)
# loss_true1 = 0.014987852f0 (tracked)
# cntr = 6500
# loss_FD = -39.43296705611695 (tracked)
# loss_true1 = 0.014768138f0 (tracked)
# cntr = 7000
# loss_FD = -39.46973888888054 (tracked)
# loss_true1 = 0.015940243f0 (tracked)
# cntr = 7500
# loss_FD = -39.43396458268258 (tracked)
# loss_true1 = 0.019299386f0 (tracked)
# cntr = 8000
# loss_FD = -39.41322266955456 (tracked)
# loss_true1 = 0.015470501f0 (tracked)
# cntr = 8500
# loss_FD = -39.53294628024535 (tracked)
# loss_true1 = 0.014576986f0 (tracked)
# cntr = 9000
# loss_FD = -39.45127954179419 (tracked)
# loss_true1 = 0.015347656f0 (tracked)
# cntr = 9500
# loss_FD = -39.46246172197482 (tracked)
# loss_true1 = 0.015195389f0 (tracked)
# cntr = 10000
# loss_FD = -39.444342315166594 (tracked)
# loss_true1 = 0.01487763f0 (tracked)
# cntr = 10500
# loss_FD = -39.5025272889349 (tracked)
# loss_true1 = 0.0154013485f0 (tracked)
# cntr = 11000
# loss_FD = -39.47883944910092 (tracked)
# loss_true1 = 0.016320786f0 (tracked)
# cntr = 11500
# loss_FD = -39.46124905398178 (tracked)
# loss_true1 = 0.015814338f0 (tracked)
# cntr = 12000
# loss_FD = -39.4704702125779 (tracked)
# loss_true1 = 0.016944041f0 (tracked)
# cntr = 12500
# loss_FD = -39.44938171845757 (tracked)
# loss_true1 = 0.015605884f0 (tracked)
# cntr = 13000
# loss_FD = -39.49214975811576 (tracked)
# loss_true1 = 0.015145683f0 (tracked)
# cntr = 13500
# loss_FD = -39.47977633978884 (tracked)
# loss_true1 = 0.0153546175f0 (tracked)
# cntr = 14000
# loss_FD = -39.46477412282867 (tracked)
# loss_true1 = 0.01575203f0 (tracked)
# cntr = 14500
# loss_FD = -39.495845611855856 (tracked)
# loss_true1 = 0.01474586f0 (tracked)
# cntr = 15000
# loss_FD = -39.476090355497206 (tracked)
# loss_true1 = 0.016095743f0 (tracked)
# cntr = 15500
# loss_FD = -39.47601289778089 (tracked)
# loss_true1 = 0.016524047f0 (tracked)
# cntr = 16000
# loss_FD = -39.4830849265728 (tracked)
# loss_true1 = 0.014585409f0 (tracked)
# cntr = 16500
# loss_FD = -39.486622425218854 (tracked)
# loss_true1 = 0.015497848f0 (tracked)
# cntr = 17000
# loss_FD = -39.42891444571078 (tracked)
# loss_true1 = 0.015051909f0 (tracked)
# cntr = 17500
# loss_FD = -39.47647729553738 (tracked)
# loss_true1 = 0.01584377f0 (tracked)
# cntr = 18000
# loss_FD = -39.501968759737835 (tracked)
# loss_true1 = 0.013813503f0 (tracked)
# cntr = 18500
# loss_FD = -39.4475118907087 (tracked)
# loss_true1 = 0.016257223f0 (tracked)
# cntr = 19000
# loss_FD = -39.484895108171536 (tracked)
# loss_true1 = 0.01393128f0 (tracked)
# cntr = 19500
# loss_FD = -39.47336239951138 (tracked)
# loss_true1 = 0.014369459f0 (tracked)
# cntr = 20000
# loss_FD = -39.46835622499434 (tracked)
# loss_true1 = 0.013659829f0 (tracked)
