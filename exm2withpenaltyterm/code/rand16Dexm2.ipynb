# %%
using Flux.Tracker
using Flux
using Flux:throttle,glorot_uniform
using BSON:@save
using BSON:@load
using Base.Iterators: repeated
using Flux:@treelike
using PyPlot
using FastGaussQuadrature
using SparseGrids
using LinearAlgebra
using Flux: @epochs
using DataFrames
using CSV
using Sobol
using Pkg; Pkg.activate("cuda"); Pkg.instantiate()
using CuArrays
using ForwardDiff
using CUDAnative
CuArrays.culiteral_pow(::typeof(^), x::ForwardDiff.Dual{Nothing,Float32,1}, ::Val{2}) = x*x
CuArrays.culiteral_pow(::typeof(^), x::ForwardDiff.Dual{Nothing,Float64,1}, ::Val{2}) = x*x

f(x)=2*π^2 .*sum(cos.(π*x[i,:]') for i=1:16, dims=1)
acti(x)=@. x/(1+CUDAnative.exp(-x))


struct Block{F,S,T}
  W1::S
  W2::S
  b1::T
  b2::T
  σ::F
end

Block(W1 , W2, b1, b2) = Block(W1,W2 ,b1 ,b2, identity)

function Block(in1::Integer,in2::Integer, out1::Integer,out2::Integer, σ = identity;
  initW1 = glorot_uniform, initW2 =glorot_uniform, initb1 = zeros,initb2=zeros)
  return Block(param(initW1(out1, in1)),param(initW2(out2,in2)), param(initb1(out1)), param(initb2(out2)),σ)
end

@treelike Block

function (a::Block)(x)
  W1,W2, b1,b2, σ = a.W1,a.W2,a.b1, a.b2, a.σ
  σ.(W2 *σ.(W1*x .+ b1) .+ b2) .+ x
end





M=Chain(
Dense(16,48),
Block(48,48,48,48,acti),
Block(48,48,48,48,acti),
Block(48,48,48,48,acti),
Block(48,48,48,48,acti),
Block(48,48,48,48,acti),
Dense(48,1)
)|>gpu

function lossFD(N)
  notes=rand(16,N)
  notes =notes |>gpu
  d=rand(1)/100 |>gpu
  losses=0
  MMM=M(notes)
  for i=1:16
    l1=zeros(16)
    l1[i]=1
    l1 = l1 |>gpu
    losses  += (sum(0.5*((M(notes .+ d.*l1) .- MMM)./d).^2)/N)[1]
  end
  losses += (sum(0.5*(π^2 * (MMM).^2))/N)[1]
  losses += (sum(-f(notes) .*MMM)/N)[1]
  return losses
end


function lossBC(β)
  d=(rand(1)/100)|>gpu
  point=zeros(16,3200)
  p=rand(15,100)
  for i=1:16
    point[:,200*(i-1)+1:200*(i-1)+100]=vcat(p[1:i-1,:],zeros(100)',p[i:end,:])
    point[:,200*(i-1)+101:200*i]=vcat(p[1:i-1,:], ones(100)',p[i:end,:])
  end
    point=point|>gpu
  losses=0
  for i=1:16
    l1=zeros(16)
    l1[i]=1
    l1=l1|>gpu
    losses +=β*(sum((( 1/2*M(point[:,200*(i-1)+1:200*i] .+ d.*l1) .- 1/2*M(point[:,200*(i-1)+1:200*i] .- d.*l1))./d).^2)/100)[1]
  end
  return losses
end

function loss1(N)
  return lossBC(50)+lossFD(N)
end


function loss_true(xx=1,yy=1,xx1=1,xx2=2)
  points=zeros(16,5000)
    for i=1:5000
      points[:,i]=next!(truep)
    end
    points=points  |>gpu
  F_true(x)= sum(cos.(pi*x[i,:]') for i=1:16, dims=1)
  errors=sqrt(sum((M(points)-F_true(points)).^2)/5000)
  return errors
end


inner=SobolSeq(16)
truep=SobolSeq(16)
BC=SobolSeq(15)


function test(N;traintime=2000)
  errdf=DataFrame(time=Int[],absolute_error=Float64[],loss_FD=Float64[],loss_BC=Float64[])
  cntr=1
  evalcb = function()
    loss_true1=loss_true()
    loss_FD = lossFD(N)
    loss_BC =lossBC(1)
    push!(errdf,[Tracker.data(cntr),Tracker.data(loss_true1),Tracker.data(loss_FD),Tracker.data(loss_BC)])
    cntr+=1
    if cntr%1000==0
      @show(cntr,loss_FD,loss_true1,loss_BC)
      CSV.write("$(N)rand16Dexm2.csv",errdf)
      @save "$(N)randpoint16Dexm2m.bson" M
      weights=Tracker.data.(params(M))
      @save "$(N)randpoint16Dexm2w.bson" weights
    end
  end
  θ=Flux.params(M)
  opt=ADAM()
  dataset=[(N) for i=1:traintime]
  Flux.train!(loss1, params(M), zip(dataset), opt, cb=evalcb)
  return errdf
end
# Out:
# ┌ Info: Precompiling Flux [587475ba-b771-5e3f-ad9e-33799f191a9c]
# └ @ Base loading.jl:1242
# ┌ Info: Precompiling BSON [fbb218c0-5317-5bc6-957e-2ee96dd4b1f0]
# └ @ Base loading.jl:1242
# ┌ Info: Precompiling SparseGrids [bafbe729-afc6-5148-bb4f-226bf3d46895]
# └ @ Base loading.jl:1242
# ┌ Info: Precompiling DataFrames [a93c6f00-e57d-5684-b7b6-d8193f3e46c0]
# └ @ Base loading.jl:1242
# ┌ Info: Precompiling CSV [336ed68f-0bac-5ca0-87d4-7b16caf5d00b]
# └ @ Base loading.jl:1242
# Activating new environment at `~/16Dexm2/cuda/Project.toml`
#   Updating registry at `~/.julia/registries/General`
#   Updating git-repo `https://github.com/JuliaRegistries/General.git`
#  Resolving package versions...
# ┌ Info: Building the CUDAnative run-time library for your sm_61 device, this might take a while...
# └ @ CUDAnative /root/.julia/packages/CUDAnative/LkH1v/src/compiler/rtlib.jl:168
# test (generic function with 1 method)

# %%
errdf=test(500,traintime=30000)
for i=1:4
    N=[1000 2000 5000 10000]
    errdf=test(N[i],traintime=50000)
end
# Out:
# cntr = 1000
# loss_FD = -19.525688630449324 (tracked)
# loss_true1 = 2.481211f0 (tracked)
# loss_BC = 0.06296989680272257 (tracked)
# cntr = 2000
# loss_FD = -27.146347471131246 (tracked)
# loss_true1 = 2.3172364f0 (tracked)
# loss_BC = 0.02617622278537293 (tracked)
# cntr = 3000
# loss_FD = -34.95413641679771 (tracked)
# loss_true1 = 2.1820488f0 (tracked)
# loss_BC = 0.030396658428438694 (tracked)
# cntr = 4000
# loss_FD = -47.12749156956052 (tracked)
# loss_true1 = 1.9424953f0 (tracked)
# loss_BC = 0.059307627318419855 (tracked)
# cntr = 5000
# loss_FD = -46.935382064491094 (tracked)
# loss_true1 = 1.7081114f0 (tracked)
# loss_BC = 0.05073101561654039 (tracked)
# cntr = 6000
# loss_FD = -55.19652986351254 (tracked)
# loss_true1 = 1.5925113f0 (tracked)
# loss_BC = 0.06196336761231943 (tracked)
# cntr = 7000
# loss_FD = -47.498971982456 (tracked)
# loss_true1 = 1.5749954f0 (tracked)
# loss_BC = 0.02862421738848757 (tracked)
# cntr = 8000
# loss_FD = -51.373548135244704 (tracked)
# loss_true1 = 1.563626f0 (tracked)
# loss_BC = 0.0240225681477729 (tracked)
# cntr = 9000
# loss_FD = -49.686534479435984 (tracked)
# loss_true1 = 1.553911f0 (tracked)
# loss_BC = 0.035275521720570885 (tracked)
# cntr = 10000
# loss_FD = -59.43847380927625 (tracked)
# loss_true1 = 1.4126723f0 (tracked)
# loss_BC = 0.04580179139754614 (tracked)
# cntr = 11000
# loss_FD = -59.24216958311167 (tracked)
# loss_true1 = 1.2314649f0 (tracked)
# loss_BC = 0.05872923420946084 (tracked)
# cntr = 12000
# loss_FD = -57.73831011519184 (tracked)
# loss_true1 = 1.2071825f0 (tracked)
# loss_BC = 0.025803058907064358 (tracked)
# cntr = 13000
# loss_FD = -60.84635641931091 (tracked)
# loss_true1 = 1.0139278f0 (tracked)
# loss_BC = 0.06507721705382154 (tracked)
# cntr = 14000
# loss_FD = -74.9641418072411 (tracked)
# loss_true1 = 1.0005617f0 (tracked)
# loss_BC = 0.030045057534522593 (tracked)
# cntr = 15000
# loss_FD = -76.72031437491293 (tracked)
# loss_true1 = 1.0141448f0 (tracked)
# loss_BC = 0.030335378345333022 (tracked)
# cntr = 16000
# loss_FD = -65.95827086798434 (tracked)
# loss_true1 = 0.9852418f0 (tracked)
# loss_BC = 0.023928949429326725 (tracked)
# cntr = 17000
# loss_FD = -49.69761555681839 (tracked)
# loss_true1 = 1.567853f0 (tracked)
# loss_BC = 0.03557648396893675 (tracked)
# cntr = 18000
# loss_FD = -68.15494393287076 (tracked)
# loss_true1 = 0.7225271f0 (tracked)
# loss_BC = 0.04167836908614121 (tracked)
# cntr = 19000
# loss_FD = -63.1677320823413 (tracked)
# loss_true1 = 0.71374583f0 (tracked)
# loss_BC = 0.03254301707195996 (tracked)
# cntr = 20000
# loss_FD = -71.83546622679955 (tracked)
# loss_true1 = 0.7178216f0 (tracked)
# loss_BC = 0.02726931404207547 (tracked)
# cntr = 21000
# loss_FD = -70.39035379112485 (tracked)
# loss_true1 = 0.70106536f0 (tracked)
# loss_BC = 0.02687106645647441 (tracked)
# cntr = 22000
# loss_FD = -76.77291439167914 (tracked)
# loss_true1 = 0.7053275f0 (tracked)
# loss_BC = 0.021202236891840833 (tracked)
# cntr = 23000
# loss_FD = -65.46049235343023 (tracked)
# loss_true1 = 0.7019789f0 (tracked)
# loss_BC = 0.019260594354244133 (tracked)
# cntr = 24000
# loss_FD = -68.15676116467344 (tracked)
# loss_true1 = 0.71056265f0 (tracked)
# loss_BC = 0.017871426794445002 (tracked)
# cntr = 25000
# loss_FD = -77.54582533349233 (tracked)
# loss_true1 = 0.7409161f0 (tracked)
# loss_BC = 0.018383789758260022 (tracked)
# cntr = 26000
# loss_FD = -71.69452406668202 (tracked)
# loss_true1 = 0.7084234f0 (tracked)
# loss_BC = 0.013158830632793671 (tracked)
# cntr = 27000
# loss_FD = -68.13468434558482 (tracked)
# loss_true1 = 0.7166945f0 (tracked)
# loss_BC = 0.011903924944206199 (tracked)
# cntr = 28000
# loss_FD = -80.09777678892954 (tracked)
# loss_true1 = 0.70679706f0 (tracked)
# loss_BC = 0.017211040761708773 (tracked)
# cntr = 29000
# loss_FD = -89.8531479763891 (tracked)
# loss_true1 = 0.70587516f0 (tracked)
# loss_BC = 0.011542571902394275 (tracked)
# cntr = 30000
# loss_FD = -75.4970177374646 (tracked)
# loss_true1 = 0.70191026f0 (tracked)
# loss_BC = 0.014075086761729546 (tracked)
# cntr = 1000
# loss_FD = -78.41581781135937 (tracked)
# loss_true1 = 0.70324314f0 (tracked)
# loss_BC = 0.010135582736061072 (tracked)
# cntr = 2000
# loss_FD = -80.26532880069848 (tracked)
# loss_true1 = 0.7015636f0 (tracked)
# loss_BC = 0.00943498914046907 (tracked)
# cntr = 3000
# loss_FD = -85.67483649188733 (tracked)
# loss_true1 = 0.699707f0 (tracked)
# loss_BC = 0.014790837945615063 (tracked)
# cntr = 4000
# loss_FD = -25.29920136566114 (tracked)
# loss_true1 = 2.439129f0 (tracked)
# loss_BC = 2.19318315267945 (tracked)
# cntr = 5000
# loss_FD = -23.47522374012756 (tracked)
# loss_true1 = 2.3871636f0 (tracked)
# loss_BC = 0.8115441299890185 (tracked)
# cntr = 6000
# loss_FD = -21.939006591039735 (tracked)
# loss_true1 = 2.381098f0 (tracked)
# loss_BC = 0.43046186193586305 (tracked)
# cntr = 7000
# loss_FD = -24.840947981398674 (tracked)
# loss_true1 = 2.3509145f0 (tracked)
# loss_BC = 0.2973059483155909 (tracked)
# cntr = 8000
# loss_FD = -23.66128526003515 (tracked)
# loss_true1 = 2.297103f0 (tracked)
# loss_BC = 0.26290151120279354 (tracked)
# cntr = 9000
# loss_FD = -30.541773109920793 (tracked)
# loss_true1 = 2.209875f0 (tracked)
# loss_BC = 0.21166372667920805 (tracked)
# cntr = 10000
# loss_FD = -35.56416378396217 (tracked)
# loss_true1 = 2.0643198f0 (tracked)
# loss_BC = 0.20699804349439643 (tracked)
# cntr = 11000
# loss_FD = -42.588688679387495 (tracked)
# loss_true1 = 1.856162f0 (tracked)
# loss_BC = 0.20796676961632068 (tracked)
# cntr = 12000
# loss_FD = -51.613674390221995 (tracked)
# loss_true1 = 1.5845654f0 (tracked)
# loss_BC = 0.223621591973397 (tracked)
# cntr = 13000
# loss_FD = -59.3067891309229 (tracked)
# loss_true1 = 1.3216497f0 (tracked)
# loss_BC = 0.19843072725617983 (tracked)
# cntr = 14000
# loss_FD = -65.62992556122062 (tracked)
# loss_true1 = 1.1296779f0 (tracked)
# loss_BC = 0.15801086734274924 (tracked)
# cntr = 15000
# loss_FD = -59.803749862085006 (tracked)
# loss_true1 = 1.0169954f0 (tracked)
# loss_BC = 0.12906360682075405 (tracked)
# cntr = 16000
# loss_FD = -67.96457389966702 (tracked)
# loss_true1 = 0.9539012f0 (tracked)
# loss_BC = 0.09413416322365127 (tracked)
# cntr = 17000
# loss_FD = -74.75419192370441 (tracked)
# loss_true1 = 0.8130126f0 (tracked)
# loss_BC = 0.06828840712794322 (tracked)
# cntr = 18000
# loss_FD = -65.50207623037899 (tracked)
# loss_true1 = 0.74646205f0 (tracked)
# loss_BC = 0.05434716991416023 (tracked)
# cntr = 19000
# loss_FD = -78.42492723435754 (tracked)
# loss_true1 = 0.72171f0 (tracked)
# loss_BC = 0.04446061654677927 (tracked)
# cntr = 20000
# loss_FD = -78.71458267435719 (tracked)
# loss_true1 = 0.70920664f0 (tracked)
# loss_BC = 0.03499148548582178 (tracked)
# cntr = 21000
# loss_FD = -82.50923377544879 (tracked)
# loss_true1 = 0.70289737f0 (tracked)
# loss_BC = 0.026244212780739153 (tracked)
# cntr = 22000
# loss_FD = -72.92504947642946 (tracked)
# loss_true1 = 0.6899734f0 (tracked)
# loss_BC = 0.028020877217696593 (tracked)
# cntr = 23000
# loss_FD = -71.76877667035572 (tracked)
# loss_true1 = 0.58892226f0 (tracked)
# loss_BC = 0.032373405555878455 (tracked)
# cntr = 24000
# loss_FD = -76.91708916289167 (tracked)
# loss_true1 = 0.17174655f0 (tracked)
# loss_BC = 0.034033541062021125 (tracked)
# cntr = 25000
# loss_FD = -82.68228722196706 (tracked)
# loss_true1 = 0.13131833f0 (tracked)
# loss_BC = 0.026770354608523967 (tracked)
# cntr = 26000
# loss_FD = -81.69028265431712 (tracked)
# loss_true1 = 0.15241925f0 (tracked)
# loss_BC = 0.029028040660786503 (tracked)
# cntr = 27000
# loss_FD = -79.32031290242682 (tracked)
# loss_true1 = 0.095116846f0 (tracked)
# loss_BC = 0.027094885838748806 (tracked)
# cntr = 28000
# loss_FD = -68.39601779464411 (tracked)
# loss_true1 = 0.0883791f0 (tracked)
# loss_BC = 0.020255548896373782 (tracked)
# cntr = 29000
# loss_FD = -75.74716066933631 (tracked)
# loss_true1 = 0.09807257f0 (tracked)
# loss_BC = 0.019757515241725476 (tracked)
# cntr = 30000
# loss_FD = -86.27056103781052 (tracked)
# loss_true1 = 0.1184663f0 (tracked)
# loss_BC = 0.02415873608132836 (tracked)
# cntr = 31000
# loss_FD = -74.95545126481505 (tracked)
# loss_true1 = 0.08799831f0 (tracked)
# loss_BC = 0.01809977476440762 (tracked)
# cntr = 32000
# loss_FD = -77.78355365037177 (tracked)
# loss_true1 = 0.11129919f0 (tracked)
# loss_BC = 0.0167640376891646 (tracked)
# cntr = 33000
# loss_FD = -79.58173190581431 (tracked)
# loss_true1 = 0.11345661f0 (tracked)
# loss_BC = 0.01707810530253107 (tracked)
# cntr = 34000
# loss_FD = -85.97002304187964 (tracked)
# loss_true1 = 0.08632458f0 (tracked)
# loss_BC = 0.014543720415812452 (tracked)
# cntr = 35000
# loss_FD = -81.37825447919653 (tracked)
# loss_true1 = 0.085429475f0 (tracked)
# loss_BC = 0.015513422427250102 (tracked)
# cntr = 36000
# loss_FD = -74.51880077015657 (tracked)
# loss_true1 = 0.08752469f0 (tracked)
# loss_BC = 0.014232981480811766 (tracked)
# cntr = 37000
# loss_FD = -81.71168973696639 (tracked)
# loss_true1 = 0.16153972f0 (tracked)
# loss_BC = 0.01232945590953666 (tracked)
# cntr = 38000
# loss_FD = -70.92073387211462 (tracked)
# loss_true1 = 0.08599121f0 (tracked)
# loss_BC = 0.01924758563898435 (tracked)
# cntr = 39000
# loss_FD = -78.57381526597402 (tracked)
# loss_true1 = 0.13024403f0 (tracked)
# loss_BC = 0.010238559178423276 (tracked)
# cntr = 40000
# loss_FD = -71.09109083500921 (tracked)
# loss_true1 = 0.12472065f0 (tracked)
# loss_BC = 0.015708422643285484 (tracked)
# cntr = 41000
# loss_FD = -81.37323300970925 (tracked)
# loss_true1 = 0.09926249f0 (tracked)
# loss_BC = 0.01422299314051003 (tracked)
# cntr = 42000
# loss_FD = -82.08097259940382 (tracked)
# loss_true1 = 0.048950583f0 (tracked)
# loss_BC = 0.015109917508829956 (tracked)
# cntr = 43000
# loss_FD = -83.76401245337084 (tracked)
# loss_true1 = 0.06289853f0 (tracked)
# loss_BC = 0.009371545588783534 (tracked)
# cntr = 44000
# loss_FD = -87.98130287954667 (tracked)
# loss_true1 = 0.05532147f0 (tracked)
# loss_BC = 0.008506515805841141 (tracked)
# cntr = 45000
# loss_FD = -86.91361920895099 (tracked)
# loss_true1 = 0.047757804f0 (tracked)
# loss_BC = 0.009353922111952948 (tracked)
# cntr = 46000
# loss_FD = -75.69083866019747 (tracked)
# loss_true1 = 0.066094495f0 (tracked)
# loss_BC = 0.006539620679089075 (tracked)
# cntr = 47000
# loss_FD = -83.13182103531119 (tracked)
# loss_true1 = 0.108887054f0 (tracked)
# loss_BC = 0.008662975035838447 (tracked)
# cntr = 48000
# loss_FD = -83.7988340964166 (tracked)
# loss_true1 = 0.061503075f0 (tracked)
# loss_BC = 0.011885596424362354 (tracked)
# cntr = 49000
# loss_FD = -78.77875163249729 (tracked)
# loss_true1 = 0.06660025f0 (tracked)
# loss_BC = 0.008937298053247871 (tracked)
# cntr = 50000
# loss_FD = -69.48960591490237 (tracked)
# loss_true1 = 0.1733861f0 (tracked)
# loss_BC = 0.014272463239167876 (tracked)
# cntr = 1000
# loss_FD = -81.5978049615209 (tracked)
# loss_true1 = 0.044015586f0 (tracked)
# loss_BC = 0.0054242202861881144 (tracked)
# cntr = 2000
# loss_FD = -76.57669407029871 (tracked)
# loss_true1 = 0.049910598f0 (tracked)
# loss_BC = 0.008193242407999657 (tracked)
# cntr = 3000
# loss_FD = -85.86460507823331 (tracked)
# loss_true1 = 0.059796855f0 (tracked)
# loss_BC = 0.012844004053050608 (tracked)
# cntr = 4000
# loss_FD = -74.9726411600287 (tracked)
# loss_true1 = 0.070458286f0 (tracked)
# loss_BC = 0.007095859577850855 (tracked)
# cntr = 5000
# loss_FD = -75.82062560250641 (tracked)
# loss_true1 = 0.09402719f0 (tracked)
# loss_BC = 0.007017500666900636 (tracked)
# cntr = 6000
# loss_FD = -75.84453433581282 (tracked)
# loss_true1 = 0.06258131f0 (tracked)
# loss_BC = 0.008382117802235908 (tracked)
# cntr = 7000
# loss_FD = -83.01230176148064 (tracked)
# loss_true1 = 0.11980961f0 (tracked)
# loss_BC = 0.005863800121662217 (tracked)
# cntr = 8000
# loss_FD = -73.435262580323 (tracked)
# loss_true1 = 0.06601512f0 (tracked)
# loss_BC = 0.005835889180253832 (tracked)
# cntr = 9000
# loss_FD = -82.21476985730745 (tracked)
# loss_true1 = 0.043028977f0 (tracked)
# loss_BC = 0.005820722298346965 (tracked)
# cntr = 10000
# loss_FD = -84.06687069595617 (tracked)
# loss_true1 = 0.070657484f0 (tracked)
# loss_BC = 0.00923561797619191 (tracked)
# cntr = 11000
# loss_FD = -85.27218355792371 (tracked)
# loss_true1 = 0.040527277f0 (tracked)
# loss_BC = 0.00821297798191392 (tracked)
# cntr = 12000
# loss_FD = -74.98821172487368 (tracked)
# loss_true1 = 0.052757353f0 (tracked)
# loss_BC = 0.004043264178090686 (tracked)
# cntr = 13000
# loss_FD = -79.49552932968216 (tracked)
# loss_true1 = 0.10224485f0 (tracked)
# loss_BC = 0.015109089292152371 (tracked)
# cntr = 14000
# loss_FD = -75.11021540609319 (tracked)
# loss_true1 = 0.069193415f0 (tracked)
# loss_BC = 0.006405945547285581 (tracked)
# cntr = 15000
# loss_FD = -74.81913643446126 (tracked)
# loss_true1 = 0.061119538f0 (tracked)
# loss_BC = 0.0041115112487718295 (tracked)
# cntr = 16000
# loss_FD = -73.1220022812509 (tracked)
# loss_true1 = 0.06178342f0 (tracked)
# loss_BC = 0.007251683018057347 (tracked)
# cntr = 17000
# loss_FD = -78.62809909169087 (tracked)
# loss_true1 = 0.10414099f0 (tracked)
# loss_BC = 0.01729537708800951 (tracked)
# cntr = 18000
# loss_FD = -82.39363801665286 (tracked)
# loss_true1 = 0.050973672f0 (tracked)
# loss_BC = 0.006465707408559526 (tracked)
# cntr = 19000
# loss_FD = -76.79681196716899 (tracked)
# loss_true1 = 0.0734695f0 (tracked)
# loss_BC = 0.006854197709962009 (tracked)
# cntr = 20000
# loss_FD = -77.03391978390314 (tracked)
# loss_true1 = 0.06973542f0 (tracked)
# loss_BC = 0.005349021415300526 (tracked)
# cntr = 21000
# loss_FD = -79.10423838966449 (tracked)
# loss_true1 = 0.09262584f0 (tracked)
# loss_BC = 0.00709679341507972 (tracked)
# cntr = 22000
# loss_FD = -80.7365371066014 (tracked)
# loss_true1 = 0.096380934f0 (tracked)
# loss_BC = 0.005958161706461974 (tracked)
# cntr = 23000
# loss_FD = -74.99814091486215 (tracked)
# loss_true1 = 0.04589397f0 (tracked)
# loss_BC = 0.009760087240548523 (tracked)
# cntr = 24000
# loss_FD = -81.68172751583367 (tracked)
# loss_true1 = 0.07260077f0 (tracked)
# loss_BC = 0.010045280334398827 (tracked)
# cntr = 25000
# loss_FD = -82.60484679311969 (tracked)
# loss_true1 = 0.064414285f0 (tracked)
# loss_BC = 0.003423846921152602 (tracked)
# cntr = 26000
# loss_FD = -82.20013212450107 (tracked)
# loss_true1 = 0.09201206f0 (tracked)
# loss_BC = 0.004883118718159343 (tracked)
# cntr = 27000
# loss_FD = -78.90284774306635 (tracked)
# loss_true1 = 0.050305817f0 (tracked)
# loss_BC = 0.007375333856127553 (tracked)
# cntr = 28000
# loss_FD = -77.0737994572554 (tracked)
# loss_true1 = 0.046929017f0 (tracked)
# loss_BC = 0.006337192905842169 (tracked)
# cntr = 29000
# loss_FD = -71.5926963595345 (tracked)
# loss_true1 = 0.047492094f0 (tracked)
# loss_BC = 0.004860498304057577 (tracked)
# cntr = 30000
# loss_FD = -82.47506617439547 (tracked)
# loss_true1 = 0.03328699f0 (tracked)
# loss_BC = 0.005758653233740162 (tracked)
# cntr = 31000
# loss_FD = -83.42992245026112 (tracked)
# loss_true1 = 0.04399953f0 (tracked)
# loss_BC = 0.007095265700727866 (tracked)
# cntr = 32000
# loss_FD = -82.2715511958232 (tracked)
# loss_true1 = 0.050917022f0 (tracked)
# loss_BC = 0.004946749662993076 (tracked)
# cntr = 33000
# loss_FD = -78.54753687329446 (tracked)
# loss_true1 = 0.059099257f0 (tracked)
# loss_BC = 0.003004140263786669 (tracked)
# cntr = 34000
# loss_FD = -75.17583788426563 (tracked)
# loss_true1 = 0.1405985f0 (tracked)
# loss_BC = 0.005932607792492847 (tracked)
# cntr = 35000
# loss_FD = -77.99096055155263 (tracked)
# loss_true1 = 0.043493737f0 (tracked)
# loss_BC = 0.00773888133503167 (tracked)
# cntr = 36000
# loss_FD = -88.75479952705734 (tracked)
# loss_true1 = 0.04354583f0 (tracked)
# loss_BC = 0.007299913859631036 (tracked)
# cntr = 37000
# loss_FD = -72.80146003893758 (tracked)
# loss_true1 = 0.06025486f0 (tracked)
# loss_BC = 0.0026190819992685053 (tracked)
# cntr = 38000
# loss_FD = -78.65526367181496 (tracked)
# loss_true1 = 0.10244965f0 (tracked)
# loss_BC = 0.006705108516704944 (tracked)
# cntr = 39000
# loss_FD = -79.20881161329643 (tracked)
# loss_true1 = 0.053593587f0 (tracked)
# loss_BC = 0.007348659393047959 (tracked)
# cntr = 40000
# loss_FD = -78.72813454103101 (tracked)
# loss_true1 = 0.07831368f0 (tracked)
# loss_BC = 0.0045594687298665705 (tracked)
# cntr = 41000
# loss_FD = -76.21748987009519 (tracked)
# loss_true1 = 0.03844206f0 (tracked)
# loss_BC = 0.004184122227277396 (tracked)
# cntr = 42000
# loss_FD = -76.755936220879 (tracked)
# loss_true1 = 0.06818361f0 (tracked)
# loss_BC = 0.0076146992162011125 (tracked)
# cntr = 43000
# loss_FD = -69.2164906491296 (tracked)
# loss_true1 = 0.108690545f0 (tracked)
# loss_BC = 0.003228262995179011 (tracked)
# cntr = 44000
# loss_FD = -76.74551457869583 (tracked)
# loss_true1 = 0.061111726f0 (tracked)
# loss_BC = 0.003517535317917467 (tracked)
# cntr = 45000
# loss_FD = -79.37230343703243 (tracked)
# loss_true1 = 0.04599639f0 (tracked)
# loss_BC = 0.003634148392373653 (tracked)
# cntr = 46000
# loss_FD = -80.08859651913022 (tracked)
# loss_true1 = 0.03928853f0 (tracked)
# loss_BC = 0.00536763023083481 (tracked)
# cntr = 47000
# loss_FD = -81.61074462376239 (tracked)
# loss_true1 = 0.119388156f0 (tracked)
# loss_BC = 0.006673806426705731 (tracked)
# cntr = 48000
# loss_FD = -75.64426071594099 (tracked)
# loss_true1 = 0.038089477f0 (tracked)
# loss_BC = 0.003029429362810601 (tracked)
# cntr = 49000
# loss_FD = -76.43323612121668 (tracked)
# loss_true1 = 0.03759109f0 (tracked)
# loss_BC = 0.005519055020088453 (tracked)
# cntr = 50000
# loss_FD = -85.21540641512742 (tracked)
# loss_true1 = 0.07433978f0 (tracked)
# loss_BC = 0.0034780593790309355 (tracked)
# cntr = 1000
# loss_FD = -79.31783955877832 (tracked)
# loss_true1 = 0.045748882f0 (tracked)
# loss_BC = 0.00277814649482918 (tracked)
# cntr = 2000
# loss_FD = -78.80496590412795 (tracked)
# loss_true1 = 0.032260925f0 (tracked)
# loss_BC = 0.003695299862312681 (tracked)
# cntr = 3000
# loss_FD = -80.60986692702329 (tracked)
# loss_true1 = 0.05516353f0 (tracked)
# loss_BC = 0.004189870427622248 (tracked)
# cntr = 4000
# loss_FD = -76.20336972645492 (tracked)
# loss_true1 = 0.040186226f0 (tracked)
# loss_BC = 0.0038915915081914284 (tracked)
# cntr = 5000
# loss_FD = -48.381349176445546 (tracked)
# loss_true1 = 1.7906055f0 (tracked)
# loss_BC = 0.040886130881543366 (tracked)
# cntr = 6000
# loss_FD = -79.90842662366163 (tracked)
# loss_true1 = 0.13280821f0 (tracked)
# loss_BC = 0.02846981828543376 (tracked)
# cntr = 7000
# loss_FD = -82.95770035870768 (tracked)
# loss_true1 = 0.09035478f0 (tracked)
# loss_BC = 0.01216017203336866 (tracked)
# cntr = 8000
# loss_FD = -80.67265271566015 (tracked)
# loss_true1 = 0.0725688f0 (tracked)
# loss_BC = 0.00857725443118852 (tracked)
# cntr = 9000
# loss_FD = -80.99546906321396 (tracked)
# loss_true1 = 0.06887416f0 (tracked)
# loss_BC = 0.007787037129997651 (tracked)
# cntr = 10000
# loss_FD = -76.16228798767693 (tracked)
# loss_true1 = 0.075094916f0 (tracked)
# loss_BC = 0.0046552291610824055 (tracked)
# cntr = 11000
# loss_FD = -78.74980513356326 (tracked)
# loss_true1 = 0.0466591f0 (tracked)
# loss_BC = 0.007307118610213425 (tracked)
# cntr = 12000
# loss_FD = -77.86700235980874 (tracked)
# loss_true1 = 0.042807933f0 (tracked)
# loss_BC = 0.00508896780681856 (tracked)
# cntr = 13000
# loss_FD = -78.60705011713853 (tracked)
# loss_true1 = 0.05962409f0 (tracked)
# loss_BC = 0.005922776957351715 (tracked)
# cntr = 14000
# loss_FD = -77.30050858964808 (tracked)
# loss_true1 = 0.042263467f0 (tracked)
# loss_BC = 0.005876885968485525 (tracked)
# cntr = 15000
# loss_FD = -80.53089299356512 (tracked)
# loss_true1 = 0.04392358f0 (tracked)
# loss_BC = 0.003603928593466514 (tracked)
# cntr = 16000
# loss_FD = -75.51045256617377 (tracked)
# loss_true1 = 0.042643268f0 (tracked)
# loss_BC = 0.007267347848549025 (tracked)
# cntr = 17000
# loss_FD = -78.9648896354847 (tracked)
# loss_true1 = 0.04103731f0 (tracked)
# loss_BC = 0.005234748969457221 (tracked)
# cntr = 18000
# loss_FD = -76.69095166335325 (tracked)
# loss_true1 = 0.118546136f0 (tracked)
# loss_BC = 0.003253311571626181 (tracked)
# cntr = 19000
# loss_FD = -75.42763527693312 (tracked)
# loss_true1 = 0.051437188f0 (tracked)
# loss_BC = 0.0035887268935705734 (tracked)
# cntr = 20000
# loss_FD = -82.44192517762221 (tracked)
# loss_true1 = 0.071232714f0 (tracked)
# loss_BC = 0.003870102569117006 (tracked)
# cntr = 21000
# loss_FD = -80.74286224849922 (tracked)
# loss_true1 = 0.03668435f0 (tracked)
# loss_BC = 0.0037029803213075485 (tracked)
# cntr = 22000
# loss_FD = -80.82378509207103 (tracked)
# loss_true1 = 0.041662168f0 (tracked)
# loss_BC = 0.0035766452212403588 (tracked)
# cntr = 23000
# loss_FD = -78.65444638204141 (tracked)
# loss_true1 = 0.065497205f0 (tracked)
# loss_BC = 0.009470899181300061 (tracked)
# cntr = 24000
# loss_FD = -80.17817987052999 (tracked)
# loss_true1 = 0.036638997f0 (tracked)
# loss_BC = 0.002382564531964932 (tracked)
# cntr = 25000
# loss_FD = -78.28482405975056 (tracked)
# loss_true1 = 0.03252917f0 (tracked)
# loss_BC = 0.002891724000940244 (tracked)
# cntr = 26000
# loss_FD = -79.95896612583496 (tracked)
# loss_true1 = 0.049662367f0 (tracked)
# loss_BC = 0.002336918220281661 (tracked)
# cntr = 27000
# loss_FD = -79.91362898309697 (tracked)
# loss_true1 = 0.03442915f0 (tracked)
# loss_BC = 0.0035347933513995952 (tracked)
# cntr = 28000
# loss_FD = -77.36233803429727 (tracked)
# loss_true1 = 0.032773428f0 (tracked)
# loss_BC = 0.004358842864342532 (tracked)
# cntr = 29000
# loss_FD = -62.423573181221556 (tracked)
# loss_true1 = 1.0488782f0 (tracked)
# loss_BC = 0.011025138606496596 (tracked)
# cntr = 30000
# loss_FD = -78.42823431892663 (tracked)
# loss_true1 = 0.042284437f0 (tracked)
# loss_BC = 0.0031737415806549546 (tracked)
# cntr = 31000
# loss_FD = -78.44970377220596 (tracked)
# loss_true1 = 0.04096886f0 (tracked)
# loss_BC = 0.002493621593633757 (tracked)
# cntr = 32000
# loss_FD = -78.99064080956555 (tracked)
# loss_true1 = 0.061867796f0 (tracked)
# loss_BC = 0.0018140499069476336 (tracked)
# cntr = 33000
# loss_FD = -78.59328463919093 (tracked)
# loss_true1 = 0.080902934f0 (tracked)
# loss_BC = 0.010768978153853553 (tracked)
# cntr = 34000
# loss_FD = -78.08920933967883 (tracked)
# loss_true1 = 0.089134775f0 (tracked)
# loss_BC = 0.005673161602411878 (tracked)
# cntr = 35000
# loss_FD = -79.54326830329991 (tracked)
# loss_true1 = 0.055535372f0 (tracked)
# loss_BC = 0.004379394228767322 (tracked)
# cntr = 36000
# loss_FD = -76.64519195014836 (tracked)
# loss_true1 = 0.15965363f0 (tracked)
# loss_BC = 0.020573862257332765 (tracked)
# cntr = 37000
# loss_FD = -78.82547594918566 (tracked)
# loss_true1 = 0.0875272f0 (tracked)
# loss_BC = 0.008771860409051542 (tracked)
# cntr = 38000
# loss_FD = -80.84282000929146 (tracked)
# loss_true1 = 0.052202355f0 (tracked)
# loss_BC = 0.007780327800800999 (tracked)
# cntr = 39000
# loss_FD = -83.29465483221955 (tracked)
# loss_true1 = 0.0761201f0 (tracked)
# loss_BC = 0.0040060952257850325 (tracked)
# cntr = 40000
# loss_FD = -78.2941284689041 (tracked)
# loss_true1 = 0.112978995f0 (tracked)
# loss_BC = 0.015880940925266953 (tracked)
# cntr = 41000
# loss_FD = -84.62785428520647 (tracked)
# loss_true1 = 0.09974816f0 (tracked)
# loss_BC = 0.00685869018333367 (tracked)
# cntr = 42000
# loss_FD = -81.20732149399268 (tracked)
# loss_true1 = 0.05904816f0 (tracked)
# loss_BC = 0.006548298669919137 (tracked)
# cntr = 43000
# loss_FD = -81.51468154696772 (tracked)
# loss_true1 = 0.052465614f0 (tracked)
# loss_BC = 0.00485247353985028 (tracked)
# cntr = 44000
# loss_FD = -80.54943703914064 (tracked)
# loss_true1 = 0.061369374f0 (tracked)
# loss_BC = 0.00639425033220406 (tracked)
# cntr = 45000
# loss_FD = -77.06491537975853 (tracked)
# loss_true1 = 0.05421501f0 (tracked)
# loss_BC = 0.006452848950145729 (tracked)
# cntr = 46000
# loss_FD = -83.44717157376283 (tracked)
# loss_true1 = 0.057604678f0 (tracked)
# loss_BC = 0.003736362780280657 (tracked)
# cntr = 47000
# loss_FD = -77.17308488682508 (tracked)
# loss_true1 = 0.08336455f0 (tracked)
# loss_BC = 0.004976947098971852 (tracked)
# cntr = 48000
# loss_FD = -81.27244209181174 (tracked)
# loss_true1 = 0.052263133f0 (tracked)
# loss_BC = 0.0027260687781119194 (tracked)
# cntr = 49000
# loss_FD = -75.84118148299332 (tracked)
# loss_true1 = 0.042484228f0 (tracked)
# loss_BC = 0.004606096329235899 (tracked)
# cntr = 50000
# loss_FD = -80.92990197586107 (tracked)
# loss_true1 = 0.036890488f0 (tracked)
# loss_BC = 0.0026041773181877067 (tracked)
# cntr = 1000
# loss_FD = -78.34493212003771 (tracked)
# loss_true1 = 0.0391233f0 (tracked)
# loss_BC = 0.001947301072713393 (tracked)
# cntr = 2000
# loss_FD = -81.93371212051207 (tracked)
# loss_true1 = 0.044412885f0 (tracked)
# loss_BC = 0.00258173403140715 (tracked)
# cntr = 3000
# loss_FD = -78.3585492162683 (tracked)
# loss_true1 = 0.03864929f0 (tracked)
# loss_BC = 0.0023783473024924268 (tracked)
# cntr = 4000
# loss_FD = -79.7535941620027 (tracked)
# loss_true1 = 0.060274806f0 (tracked)
# loss_BC = 0.00536960069376402 (tracked)
# cntr = 5000
# loss_FD = -80.47240573931774 (tracked)
# loss_true1 = 0.03723578f0 (tracked)
# loss_BC = 0.0017461711546976565 (tracked)
# cntr = 6000
# loss_FD = -79.73853424421108 (tracked)
# loss_true1 = 0.03353773f0 (tracked)
# loss_BC = 0.0035788190551496305 (tracked)
# cntr = 7000
# loss_FD = -79.0168120360244 (tracked)
# loss_true1 = 0.028956734f0 (tracked)
# loss_BC = 0.002531303992069774 (tracked)
# cntr = 8000
# loss_FD = -77.69539217837834 (tracked)
# loss_true1 = 0.041594088f0 (tracked)
# loss_BC = 0.0023609106282346244 (tracked)
# cntr = 9000
# loss_FD = -79.02724841135066 (tracked)
# loss_true1 = 0.034762524f0 (tracked)
# loss_BC = 0.002578386469159752 (tracked)
# cntr = 10000
# loss_FD = -79.99934208147987 (tracked)
# loss_true1 = 0.038939215f0 (tracked)
# loss_BC = 0.0034828691912540664 (tracked)
# cntr = 11000
# loss_FD = -79.67748399420546 (tracked)
# loss_true1 = 0.058200534f0 (tracked)
# loss_BC = 0.002307391511923668 (tracked)
# cntr = 12000
# loss_FD = -81.24301224371844 (tracked)
# loss_true1 = 0.03880471f0 (tracked)
# loss_BC = 0.001932292604186857 (tracked)
# cntr = 13000
# loss_FD = -78.12865137689823 (tracked)
# loss_true1 = 0.036108606f0 (tracked)
# loss_BC = 0.002637870897836788 (tracked)
# cntr = 14000
# loss_FD = -77.75169743275734 (tracked)
# loss_true1 = 0.053894784f0 (tracked)
# loss_BC = 0.0015702744401064868 (tracked)
# cntr = 15000
# loss_FD = -79.27562670482729 (tracked)
# loss_true1 = 0.03358482f0 (tracked)
# loss_BC = 0.003489297905881515 (tracked)
# cntr = 16000
# loss_FD = -77.9441903877835 (tracked)
# loss_true1 = 0.054629065f0 (tracked)
# loss_BC = 0.0018128575548400354 (tracked)
# cntr = 17000
# loss_FD = -77.33105141731536 (tracked)
# loss_true1 = 0.039264955f0 (tracked)
# loss_BC = 0.002412758875492693 (tracked)
# cntr = 18000
# loss_FD = -78.92500229497068 (tracked)
# loss_true1 = 0.03508818f0 (tracked)
# loss_BC = 0.002673374926039376 (tracked)
# cntr = 19000
# loss_FD = -79.91226960461597 (tracked)
# loss_true1 = 0.06318046f0 (tracked)
# loss_BC = 0.003875079980190545 (tracked)
# cntr = 20000
# loss_FD = -79.50309327167355 (tracked)
# loss_true1 = 0.029892536f0 (tracked)
# loss_BC = 0.0025578366983867243 (tracked)
# cntr = 21000
# loss_FD = -78.24988916898329 (tracked)
# loss_true1 = 0.028103089f0 (tracked)
# loss_BC = 0.0017212684909060935 (tracked)
# cntr = 22000
# loss_FD = -77.68989278058751 (tracked)
# loss_true1 = 0.04292379f0 (tracked)
# loss_BC = 0.0009208754602153024 (tracked)
# cntr = 23000
# loss_FD = -78.6340818234662 (tracked)
# loss_true1 = 0.035756294f0 (tracked)
# loss_BC = 0.0036944489170349128 (tracked)
# cntr = 24000
# loss_FD = -78.5972754987023 (tracked)
# loss_true1 = 0.029867655f0 (tracked)
# loss_BC = 0.0012248772732898212 (tracked)
# cntr = 25000
# loss_FD = -79.0785927429093 (tracked)
# loss_true1 = 0.028063593f0 (tracked)
# loss_BC = 0.004000519249045168 (tracked)
# cntr = 26000
# loss_FD = -79.78164912216167 (tracked)
# loss_true1 = 0.05692413f0 (tracked)
# loss_BC = 0.0014579849359678783 (tracked)
# cntr = 27000
# loss_FD = -79.01803277762153 (tracked)
# loss_true1 = 0.06705937f0 (tracked)
# loss_BC = 0.0014479230531746236 (tracked)
# cntr = 28000
# loss_FD = -78.3396946850313 (tracked)
# loss_true1 = 0.044983525f0 (tracked)
# loss_BC = 0.0009502237219694112 (tracked)
# cntr = 29000
# loss_FD = -78.93488817808245 (tracked)
# loss_true1 = 0.043043282f0 (tracked)
# loss_BC = 0.0016370793066551271 (tracked)
# cntr = 30000
# loss_FD = -76.97709141215432 (tracked)
# loss_true1 = 0.04345546f0 (tracked)
# loss_BC = 0.0017627902418887052 (tracked)
# cntr = 31000
# loss_FD = -78.36264592137005 (tracked)
# loss_true1 = 0.04424729f0 (tracked)
# loss_BC = 0.0010481208851635007 (tracked)
# cntr = 32000
# loss_FD = -77.36243930896387 (tracked)
# loss_true1 = 0.030221693f0 (tracked)
# loss_BC = 0.002853166699120081 (tracked)
# cntr = 33000
# loss_FD = -77.871289232426 (tracked)
# loss_true1 = 0.027305009f0 (tracked)
# loss_BC = 0.0015125804054676095 (tracked)
# cntr = 34000
# loss_FD = -78.65910990920196 (tracked)
# loss_true1 = 0.034906525f0 (tracked)
# loss_BC = 0.0018592749808592492 (tracked)
# cntr = 35000
# loss_FD = -79.52525277551027 (tracked)
# loss_true1 = 0.0333218f0 (tracked)
# loss_BC = 0.0018259380979228136 (tracked)
# cntr = 36000
# loss_FD = -77.95105759929635 (tracked)
# loss_true1 = 0.043086827f0 (tracked)
# loss_BC = 0.0011071981521915163 (tracked)
# cntr = 37000
# loss_FD = -78.71595817312941 (tracked)
# loss_true1 = 0.43126285f0 (tracked)
# loss_BC = 0.03506782614678198 (tracked)
# cntr = 38000
# loss_FD = -80.92900543586404 (tracked)
# loss_true1 = 0.082731925f0 (tracked)
# loss_BC = 0.006461761159406943 (tracked)
# cntr = 39000
# loss_FD = -76.86996553043596 (tracked)
# loss_true1 = 0.053371128f0 (tracked)
# loss_BC = 0.0037786718685035095 (tracked)
# cntr = 40000
# loss_FD = -77.9483705092893 (tracked)
# loss_true1 = 0.06744581f0 (tracked)
# loss_BC = 0.003414830114816418 (tracked)
# cntr = 41000
# loss_FD = -78.4355090067128 (tracked)
# loss_true1 = 0.06101875f0 (tracked)
# loss_BC = 0.0028164595271135615 (tracked)
# cntr = 42000
# loss_FD = -77.33278648228892 (tracked)
# loss_true1 = 0.03509487f0 (tracked)
# loss_BC = 0.00278887912460317 (tracked)
# cntr = 43000
# loss_FD = -75.61878782990347 (tracked)
# loss_true1 = 0.14617935f0 (tracked)
# loss_BC = 0.014111783165107205 (tracked)
# cntr = 44000
# loss_FD = -82.58603718922942 (tracked)
# loss_true1 = 0.07228858f0 (tracked)
# loss_BC = 0.004943177757411828 (tracked)
# cntr = 45000
# loss_FD = -82.60478547407331 (tracked)
# loss_true1 = 0.056846313f0 (tracked)
# loss_BC = 0.0033445571515843733 (tracked)
# cntr = 46000
# loss_FD = -76.83258414659628 (tracked)
# loss_true1 = 0.042482764f0 (tracked)
# loss_BC = 0.0028839976539429143 (tracked)
# cntr = 47000
# loss_FD = -79.62061656266269 (tracked)
# loss_true1 = 0.042895015f0 (tracked)
# loss_BC = 0.0034203166912615554 (tracked)
# cntr = 48000
# loss_FD = -80.85846172717254 (tracked)
# loss_true1 = 0.045387384f0 (tracked)
# loss_BC = 0.0031128247121881836 (tracked)
# cntr = 49000
# loss_FD = -77.35983248572441 (tracked)
# loss_true1 = 0.040128578f0 (tracked)
# loss_BC = 0.0021878975483962944 (tracked)
# cntr = 50000
# loss_FD = -80.08120535639635 (tracked)
# loss_true1 = 0.03878058f0 (tracked)
# loss_BC = 0.0036293815479931596 (tracked)
